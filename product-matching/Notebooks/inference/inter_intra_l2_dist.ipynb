# %%
# !nproc & nvidia-smi -L
# Out:
# 20
# GPU 0: NVIDIA GeForce RTX 3060 (UUID: GPU-125eaf29-537f-5e5a-8a00-140ef5b42572)

# %%
import os
import time
import json
import random
import itertools
from functools import partial
from collections import defaultdict
from pprint import pprint

import pandas as pd
import numpy as np
import networkx as nx

import timm
import torch
import textdistance

import matplotlib.pyplot as plt
import seaborn as sns
import ipyplot as iplt
from IPython.display import HTML, display
from tqdm.notebook import tqdm
tqdm.pandas()

from typing import Dict, List, Any

import faiss
faiss.omp_set_num_threads(16)

data_dir = "/data/"

# %%
from dotenv import load_dotenv; load_dotenv()
from s3fs import S3FileSystem
s3 = S3FileSystem()
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
df = pd.read_parquet("s3://aisle3-ml-datasets/product-matching/aisle3/main.parquet")
df
# Out:
#                           id            variant_id  \
# 0           allsole.10491511      allsole.10491633
# 1           allsole.10491511      allsole.10491633
# 2           allsole.10491511      allsole.10491633
# 3           allsole.10491511      allsole.10491633
# 4           allsole.10491511      allsole.10491633
# ...                      ...                   ...
# 215424  ssense.221903M237021  ssense.221903M237021
# 215425  ssense.221903M237021  ssense.221903M237021
# 215426  ssense.221903M237021  ssense.221903M237021
# 215427  ssense.221903M237021  ssense.221903M237021
# 215428  ssense.221903M237021  ssense.221903M237021
#
#                                                   title merchant  brand  \
# 0                        Vans Authentic Canvas Trainers  allsole   vans
# 1                        Vans Authentic Canvas Trainers  allsole   vans
# 2                        Vans Authentic Canvas Trainers  allsole   vans
# 3                        Vans Authentic Canvas Trainers  allsole   vans
# 4                        Vans Authentic Canvas Trainers  allsole   vans
# ...                                                 ...      ...    ...
# 215424  Coach 1941 Black & Off-White Logo Slide Sandals   ssense  coach
# 215425  Coach 1941 Black & Off-White Logo Slide Sandals   ssense  coach
# 215426  Coach 1941 Black & Off-White Logo Slide Sandals   ssense  coach
# 215427  Coach 1941 Black & Off-White Logo Slide Sandals   ssense  coach
# 215428  Coach 1941 Black & Off-White Logo Slide Sandals   ssense  coach
#
#         gender        color   imid  \
# 0       unisex        Black  26789
# 1       unisex        Black  26790
# 2       unisex        Black  26791
# 3       unisex        Black  26792
# 4       unisex        Black  26793
# ...        ...          ...    ...
# 215424     men  Chalk black  95785
# 215425     men  Chalk black  95786
# 215426     men  Chalk black  95787
# 215427     men  Chalk black  95788
# 215428     men  Chalk black  95789
#
#                                                 image_url  \
# 0       https://aisle-3-image-final.s3.eu-west-2.amazo...
# 1       https://aisle-3-image-final.s3.eu-west-2.amazo...
# 2       https://aisle-3-image-final.s3.eu-west-2.amazo...
# 3       https://aisle-3-image-final.s3.eu-west-2.amazo...
# 4       https://aisle-3-image-final.s3.eu-west-2.amazo...
# ...                                                   ...
# 215424  https://aisle-3-image-final.s3.eu-west-2.amazo...
# 215425  https://aisle-3-image-final.s3.eu-west-2.amazo...
# 215426  https://aisle-3-image-final.s3.eu-west-2.amazo...
# 215427  https://aisle-3-image-final.s3.eu-west-2.amazo...
# 215428  https://aisle-3-image-final.s3.eu-west-2.amazo...
#
#                                                     image          pose  \
# 0       s3://aisle-3-image-final/images/original/allso...     side_shot
# 1       s3://aisle-3-image-final/images/original/allso...     side_shot
# 2       s3://aisle-3-image-final/images/original/allso...     side_shot
# 3       s3://aisle-3-image-final/images/original/allso...    upper_shot
# 4       s3://aisle-3-image-final/images/original/allso...  partial_shot
# ...                                                   ...           ...
# 215424  s3://aisle-3-image-final/images/original/ssens...  partial_shot
# 215425  s3://aisle-3-image-final/images/original/ssens...     pair_shot
# 215426  s3://aisle-3-image-final/images/original/ssens...     side_shot
# 215427  s3://aisle-3-image-final/images/original/ssens...     pair_shot
# 215428  s3://aisle-3-image-final/images/original/ssens...     pair_shot
#
#        color_pred
# 0           black
# 1           black
# 2           black
# 3           black
# 4           black
# ...           ...
# 215424     maroon
# 215425      white
# 215426      white
# 215427      beige
# 215428     maroon
#
# [215429 rows x 12 columns]

# %%
df.image = df.image.str.replace("s3://", "") + ".jpg"
df.image
# Out:
# 0         aisle-3-image-final/images/original/allsole/al...
# 1         aisle-3-image-final/images/original/allsole/al...
# 2         aisle-3-image-final/images/original/allsole/al...
# 3         aisle-3-image-final/images/original/allsole/al...
# 4         aisle-3-image-final/images/original/allsole/al...
#                                 ...
# 215424    aisle-3-image-final/images/original/ssense/sse...
# 215425    aisle-3-image-final/images/original/ssense/sse...
# 215426    aisle-3-image-final/images/original/ssense/sse...
# 215427    aisle-3-image-final/images/original/ssense/sse...
# 215428    aisle-3-image-final/images/original/ssense/sse...
# Name: image, Length: 215429, dtype: object

# %%
(data_dir + df.image).apply(os.path.isfile).value_counts()
# Out:
# True    215429
# Name: image, dtype: int64

# %%
test_df = pd.read_parquet("product_matching_test.parquet")
test_df
# Out:
#                          id            variant_id  \
# 0      footasylum.DH9628200  footasylum.DH9628200
# 1      footasylum.DH9628200  footasylum.DH9628200
# 2      footasylum.DH9628200  footasylum.DH9628200
# 3      footasylum.DH9628200  footasylum.DH9628200
# 4      footasylum.DH9628200  footasylum.DH9628200
# ...                     ...                   ...
# 27280  footasylum.DJ4629002  footasylum.DJ4629002
# 27281  footasylum.DJ4629002  footasylum.DJ4629002
# 27282  footasylum.DJ4629002  footasylum.DJ4629002
# 27283  footasylum.DJ4629002  footasylum.DJ4629002
# 27284  footasylum.DJ4629002  footasylum.DJ4629002
#
#                                               title    merchant brand gender  \
# 0      Zoom-Type Crater 'Rad Transparency' Trainers  footasylum  nike    men
# 1      Zoom-Type Crater 'Rad Transparency' Trainers  footasylum  nike    men
# 2      Zoom-Type Crater 'Rad Transparency' Trainers  footasylum  nike    men
# 3      Zoom-Type Crater 'Rad Transparency' Trainers  footasylum  nike    men
# 4      Zoom-Type Crater 'Rad Transparency' Trainers  footasylum  nike    men
# ...                                             ...         ...   ...    ...
# 27280                            Asuna Crater Slide  footasylum  nike    men
# 27281                            Asuna Crater Slide  footasylum  nike    men
# 27282                            Asuna Crater Slide  footasylum  nike    men
# 27283                            Asuna Crater Slide  footasylum  nike    men
# 27284                            Asuna Crater Slide  footasylum  nike    men
#
#              color   imid                                          image_url  \
# 0      Multicolour  87044  https://aisle-3-image-final.s3.eu-west-2.amazo...
# 1      Multicolour  87045  https://aisle-3-image-final.s3.eu-west-2.amazo...
# 2      Multicolour  87046  https://aisle-3-image-final.s3.eu-west-2.amazo...
# 3      Multicolour  87047  https://aisle-3-image-final.s3.eu-west-2.amazo...
# 4      Multicolour  87048  https://aisle-3-image-final.s3.eu-west-2.amazo...
# ...            ...    ...                                                ...
# 27280  Multicolour  86991  https://aisle-3-image-final.s3.eu-west-2.amazo...
# 27281  Multicolour  86992  https://aisle-3-image-final.s3.eu-west-2.amazo...
# 27282  Multicolour  86993  https://aisle-3-image-final.s3.eu-west-2.amazo...
# 27283  Multicolour  86994  https://aisle-3-image-final.s3.eu-west-2.amazo...
# 27284  Multicolour  86995  https://aisle-3-image-final.s3.eu-west-2.amazo...
#
#                                                    image       pose  \
# 0      s3://aisle-3-image-final/images/original/foota...  side_shot
# 1      s3://aisle-3-image-final/images/original/foota...  side_shot
# 2      s3://aisle-3-image-final/images/original/foota...  side_shot
# 3      s3://aisle-3-image-final/images/original/foota...  pair_shot
# 4      s3://aisle-3-image-final/images/original/foota...  sole_shot
# ...                                                  ...        ...
# 27280  s3://aisle-3-image-final/images/original/foota...  side_shot
# 27281  s3://aisle-3-image-final/images/original/foota...  side_shot
# 27282  s3://aisle-3-image-final/images/original/foota...  pair_shot
# 27283  s3://aisle-3-image-final/images/original/foota...  sole_shot
# 27284  s3://aisle-3-image-final/images/original/foota...  pair_shot
#
#       color_pred  label
# 0          beige   2002
# 1          white   2002
# 2          beige   2002
# 3          white   2002
# 4          brown   2002
# ...          ...    ...
# 27280      black    843
# 27281      black    843
# 27282       navy    843
# 27283      black    843
# 27284      black    843
#
# [27285 rows x 13 columns]

# %%
test_df.id.nunique()
# Out:
# 5732

# %%
test_df.label.nunique()
# Out:
# 2454

# %%
test_df.label.max()
# Out:
# 2453

# %%
test_df.groupby("label").id.unique().apply(len).value_counts()
# Out:
# 2     1898
# 3      361
# 4      145
# 5       38
# 6        8
# 9        2
# 10       1
# 7        1
# Name: id, dtype: int64

# %%
G = nx.Graph()
test_df.groupby("label").id.unique().apply(partial(itertools.combinations, r=2)).apply(
    G.add_edges_from
)
print(
    f"Number of edges : {G.number_of_edges()} | Number of nodes : {G.number_of_nodes()}"
)

clusters = sorted(nx.connected_components(G), key=len, reverse=True)
pd.Series(clusters).apply(len).value_counts().sort_index()
# Out:
# Number of edges : 4489 | Number of nodes : 5732
# 2     1898
# 3      361
# 4      145
# 5       38
# 6        8
# 7        1
# 9        2
# 10       1
# dtype: int64

# %%
test_df = test_df.sort_values("imid").reset_index(drop=True)
test_df
# Out:
#                     id       variant_id  \
# 0        nike.13836524    nike.13836524
# 1        nike.13836524    nike.13836524
# 2        nike.13836524    nike.13836524
# 3        nike.13836524    nike.13836524
# 4        nike.13836524    nike.13836524
# ...                ...              ...
# 27280  blacks.16164868  blacks.16164868
# 27281  blacks.16164868  blacks.16164868
# 27282  blacks.16164868  blacks.16164868
# 27283  blacks.16164868  blacks.16164868
# 27284  blacks.16164868  blacks.16164868
#
#                                               title merchant    brand gender  \
# 0                       Nike Court Vision Low Shoes     nike     nike  women
# 1                       Nike Court Vision Low Shoes     nike     nike  women
# 2                       Nike Court Vision Low Shoes     nike     nike  women
# 3                       Nike Court Vision Low Shoes     nike     nike  women
# 4                       Nike Court Vision Low Shoes     nike     nike  women
# ...                                             ...      ...      ...    ...
# 27280  Salomon Alphacross Blast Trail Running Shoes   blacks  salomon    men
# 27281  Salomon Alphacross Blast Trail Running Shoes   blacks  salomon    men
# 27282  Salomon Alphacross Blast Trail Running Shoes   blacks  salomon    men
# 27283  Salomon Alphacross Blast Trail Running Shoes   blacks  salomon    men
# 27284  Salomon Alphacross Blast Trail Running Shoes   blacks  salomon    men
#
#              color    imid                                          image_url  \
# 0            Black      16  https://aisle-3-image-final.s3.eu-west-2.amazo...
# 1            Black      17  https://aisle-3-image-final.s3.eu-west-2.amazo...
# 2            Black      18  https://aisle-3-image-final.s3.eu-west-2.amazo...
# 3            Black      19  https://aisle-3-image-final.s3.eu-west-2.amazo...
# 4            Black      20  https://aisle-3-image-final.s3.eu-west-2.amazo...
# ...            ...     ...                                                ...
# 27280  Multicolour  215066  https://aisle-3-image-final.s3.eu-west-2.amazo...
# 27281  Multicolour  215067  https://aisle-3-image-final.s3.eu-west-2.amazo...
# 27282  Multicolour  215068  https://aisle-3-image-final.s3.eu-west-2.amazo...
# 27283  Multicolour  215069  https://aisle-3-image-final.s3.eu-west-2.amazo...
# 27284  Multicolour  215070  https://aisle-3-image-final.s3.eu-west-2.amazo...
#
#                                                    image          pose  \
# 0      s3://aisle-3-image-final/images/original/nike/...     side_shot
# 1      s3://aisle-3-image-final/images/original/nike/...     side_shot
# 2      s3://aisle-3-image-final/images/original/nike/...     side_shot
# 3      s3://aisle-3-image-final/images/original/nike/...     pair_shot
# 4      s3://aisle-3-image-final/images/original/nike/...     pair_shot
# ...                                                  ...           ...
# 27280  s3://aisle-3-image-final/images/original/black...     side_shot
# 27281  s3://aisle-3-image-final/images/original/black...     sole_shot
# 27282  s3://aisle-3-image-final/images/original/black...  partial_shot
# 27283  s3://aisle-3-image-final/images/original/black...  partial_shot
# 27284  s3://aisle-3-image-final/images/original/black...  partial_shot
#
#       color_pred  label
# 0          black   1503
# 1          black   1503
# 2          black   1503
# 3          black   1503
# 4          white   1503
# ...          ...    ...
# 27280      black    559
# 27281      black    559
# 27282      black    559
# 27283      black    559
# 27284      black    559
#
# [27285 rows x 13 columns]

# %%
def compute_scores(pred, gt):
    tp = len(np.intersect1d(pred, gt))
    iou = tp / len(np.union1d(pred, gt))
    # fp = np.setdiff1d(pred, gt)
    if tp == 0:
        prec, recall, f1 = (0.0, 0.0, 0.0)
    else:
        prec = tp / len(pred)
        recall = tp / len(gt)
        f1 = (2 * prec * recall) / (prec + recall)
    return {"iou": iou, "prec": prec, "recall": recall, "f1": f1}


def get_nn_imgs(imids, k=50, threshold=None):
    if isinstance(imids, int):
        imids = [imids]
    qx = features[imids]
    D, I = index.search(qx, k=k)
    if threshold is None:
        threshold = D.max()
    mask = np.argwhere(np.logical_and(I != -1, D < threshold))
    nns = list()
    for i, nn in itertools.groupby(mask, lambda x: x[0]):
        nn = np.vstack(list(nn))
        nns.append(
            [
                (idx, dist)
                for idx, dist in zip(
                    I[nn[:, 0], nn[:, 1]].tolist(), D[nn[:, 0], nn[:, 1]].tolist()
                )
            ]
        )
    return nns


def perform_blocking(nns, block_on=["gender", "brand"], block_off=["merchant"]):
    if len(nns) > 1:
        q_imid = nns[0][0]
        query = df.iloc[q_imid]
        for col in block_on:
            nns = [nn for nn in nns if query[col] == df.iloc[nn[0]][col]]
        if len(block_off):
            for col in block_off:
                nns = [nn for nn in nns if query[col] != df.iloc[nn[0]][col]]
        nns = [(q_imid, 0.0)] + nns
    return nns


def imids_to_id(imids):
    return df.iloc[imids, 0].unique()


def id_to_imids(ids):
    imids = df.loc[ids, "imid"]
    if isinstance(imids, int):
        return [imids]
    return imids


def apply_threshold(nns, threshold=0.5, similarity=False):
    return [nn[0] for nn in nns if nn[1] < threshold]

# %%
features = np.load("ld_features.npy")
print(features.shape)
# Out:
# (215429, 512)

# %%
index = faiss.IndexFlatL2(features.shape[1])
index.add(features)
index.ntotal
# Out:
# 215429

# %%
# get nns with dists
print("peforming index search")
t = time.perf_counter()
nns = get_nn_imgs(test_df.imid.values, k=100)
print("time to search:", time.perf_counter() - t)

# blocking
print("peforming blocking")
t = time.perf_counter()
nns = [perform_blocking(nn) for nn in nns]
print("time to perform blocking:", time.perf_counter() - t)

nns = dict(zip(test_df.imid.values, nns))
len(nns)
# Out:
# peforming index search
# time to search: 122.79313182999977
# peforming blocking
# time to perform blocking: 332.5137490909983
# 27285

# %%
test_df = test_df.set_index("imid", drop=False)
test_df
# Out:
#                      id       variant_id  \
# imid
# 16        nike.13836524    nike.13836524
# 17        nike.13836524    nike.13836524
# 18        nike.13836524    nike.13836524
# 19        nike.13836524    nike.13836524
# 20        nike.13836524    nike.13836524
# ...                 ...              ...
# 215066  blacks.16164868  blacks.16164868
# 215067  blacks.16164868  blacks.16164868
# 215068  blacks.16164868  blacks.16164868
# 215069  blacks.16164868  blacks.16164868
# 215070  blacks.16164868  blacks.16164868
#
#                                                title merchant    brand gender  \
# imid
# 16                       Nike Court Vision Low Shoes     nike     nike  women
# 17                       Nike Court Vision Low Shoes     nike     nike  women
# 18                       Nike Court Vision Low Shoes     nike     nike  women
# 19                       Nike Court Vision Low Shoes     nike     nike  women
# 20                       Nike Court Vision Low Shoes     nike     nike  women
# ...                                              ...      ...      ...    ...
# 215066  Salomon Alphacross Blast Trail Running Shoes   blacks  salomon    men
# 215067  Salomon Alphacross Blast Trail Running Shoes   blacks  salomon    men
# 215068  Salomon Alphacross Blast Trail Running Shoes   blacks  salomon    men
# 215069  Salomon Alphacross Blast Trail Running Shoes   blacks  salomon    men
# 215070  Salomon Alphacross Blast Trail Running Shoes   blacks  salomon    men
#
#               color    imid  \
# imid
# 16            Black      16
# 17            Black      17
# 18            Black      18
# 19            Black      19
# 20            Black      20
# ...             ...     ...
# 215066  Multicolour  215066
# 215067  Multicolour  215067
# 215068  Multicolour  215068
# 215069  Multicolour  215069
# 215070  Multicolour  215070
#
#                                                 image_url  \
# imid
# 16      https://aisle-3-image-final.s3.eu-west-2.amazo...
# 17      https://aisle-3-image-final.s3.eu-west-2.amazo...
# 18      https://aisle-3-image-final.s3.eu-west-2.amazo...
# 19      https://aisle-3-image-final.s3.eu-west-2.amazo...
# 20      https://aisle-3-image-final.s3.eu-west-2.amazo...
# ...                                                   ...
# 215066  https://aisle-3-image-final.s3.eu-west-2.amazo...
# 215067  https://aisle-3-image-final.s3.eu-west-2.amazo...
# 215068  https://aisle-3-image-final.s3.eu-west-2.amazo...
# 215069  https://aisle-3-image-final.s3.eu-west-2.amazo...
# 215070  https://aisle-3-image-final.s3.eu-west-2.amazo...
#
#                                                     image          pose  \
# imid
# 16      s3://aisle-3-image-final/images/original/nike/...     side_shot
# 17      s3://aisle-3-image-final/images/original/nike/...     side_shot
# 18      s3://aisle-3-image-final/images/original/nike/...     side_shot
# 19      s3://aisle-3-image-final/images/original/nike/...     pair_shot
# 20      s3://aisle-3-image-final/images/original/nike/...     pair_shot
# ...                                                   ...           ...
# 215066  s3://aisle-3-image-final/images/original/black...     side_shot
# 215067  s3://aisle-3-image-final/images/original/black...     sole_shot
# 215068  s3://aisle-3-image-final/images/original/black...  partial_shot
# 215069  s3://aisle-3-image-final/images/original/black...  partial_shot
# 215070  s3://aisle-3-image-final/images/original/black...  partial_shot
#
#        color_pred  label                                                nns
# imid
# 16          black   1503                                        [(16, 0.0)]
# 17          black   1503  [(17, 0.0), (107817, 0.3991560935974121), (107...
# 18          black   1503  [(18, 0.0), (109690, 0.4614090919494629), (107...
# 19          black   1503  [(19, 0.0), (107848, 0.6298296451568604), (109...
# 20          white   1503  [(20, 0.0), (107817, 0.3739442825317383), (107...
# ...           ...    ...                                                ...
# 215066      black    559                                    [(215066, 0.0)]
# 215067      black    559                                    [(215067, 0.0)]
# 215068      black    559                                    [(215068, 0.0)]
# 215069      black    559                                    [(215069, 0.0)]
# 215070      black    559                                    [(215070, 0.0)]
#
# [27285 rows x 14 columns]

# %%
test_df["nns"] = test_df.imid.map(nns)
test_df.nns
# Out:
# imid
# 16                                              [(16, 0.0)]
# 17        [(17, 0.0), (107817, 0.3991560935974121), (107...
# 18        [(18, 0.0), (109690, 0.4614090919494629), (107...
# 19        [(19, 0.0), (107848, 0.6298296451568604), (109...
# 20        [(20, 0.0), (107817, 0.3739442825317383), (107...
#                                 ...
# 215066                                      [(215066, 0.0)]
# 215067                                      [(215067, 0.0)]
# 215068                                      [(215068, 0.0)]
# 215069                                      [(215069, 0.0)]
# 215070                                      [(215070, 0.0)]
# Name: nns, Length: 27285, dtype: object
