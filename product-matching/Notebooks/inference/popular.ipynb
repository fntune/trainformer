# %%
# !nproc & nvidia-smi -L
# Out:
# 20
# GPU 0: NVIDIA GeForce RTX 3060 (UUID: GPU-125eaf29-537f-5e5a-8a00-140ef5b42572)

# %%
import os
import time
import json
import random
import itertools
from functools import partial
from collections import defaultdict
from pprint import pprint

import pandas as pd
import numpy as np
import networkx as nx

import timm
import torch
import textdistance

import matplotlib.pyplot as plt
import seaborn as sns
import ipyplot as iplt
from IPython.display import HTML, display
from tqdm.notebook import tqdm

tqdm.pandas()

from typing import Dict, List, Any

import faiss

faiss.omp_set_num_threads(16)

data_dir = "/data/"

# %%
from dotenv import load_dotenv; load_dotenv()
from s3fs import S3FileSystem
s3 = S3FileSystem()
# %load_ext sql

# %%
df = pd.read_parquet("s3://aisle3-ml-datasets/product-matching/aisle3/main.parquet")
df
# Out:
#                           id            variant_id  \
# 0           allsole.10491511      allsole.10491633
# 1           allsole.10491511      allsole.10491633
# 2           allsole.10491511      allsole.10491633
# 3           allsole.10491511      allsole.10491633
# 4           allsole.10491511      allsole.10491633
# ...                      ...                   ...
# 215424  ssense.221903M237021  ssense.221903M237021
# 215425  ssense.221903M237021  ssense.221903M237021
# 215426  ssense.221903M237021  ssense.221903M237021
# 215427  ssense.221903M237021  ssense.221903M237021
# 215428  ssense.221903M237021  ssense.221903M237021
#
#                                                   title merchant  brand  \
# 0                        Vans Authentic Canvas Trainers  allsole   vans
# 1                        Vans Authentic Canvas Trainers  allsole   vans
# 2                        Vans Authentic Canvas Trainers  allsole   vans
# 3                        Vans Authentic Canvas Trainers  allsole   vans
# 4                        Vans Authentic Canvas Trainers  allsole   vans
# ...                                                 ...      ...    ...
# 215424  Coach 1941 Black & Off-White Logo Slide Sandals   ssense  coach
# 215425  Coach 1941 Black & Off-White Logo Slide Sandals   ssense  coach
# 215426  Coach 1941 Black & Off-White Logo Slide Sandals   ssense  coach
# 215427  Coach 1941 Black & Off-White Logo Slide Sandals   ssense  coach
# 215428  Coach 1941 Black & Off-White Logo Slide Sandals   ssense  coach
#
#         gender        color   imid  \
# 0       unisex        Black  26789
# 1       unisex        Black  26790
# 2       unisex        Black  26791
# 3       unisex        Black  26792
# 4       unisex        Black  26793
# ...        ...          ...    ...
# 215424     men  Chalk black  95785
# 215425     men  Chalk black  95786
# 215426     men  Chalk black  95787
# 215427     men  Chalk black  95788
# 215428     men  Chalk black  95789
#
#                                                 image_url  \
# 0       https://aisle-3-image-final.s3.eu-west-2.amazo...
# 1       https://aisle-3-image-final.s3.eu-west-2.amazo...
# 2       https://aisle-3-image-final.s3.eu-west-2.amazo...
# 3       https://aisle-3-image-final.s3.eu-west-2.amazo...
# 4       https://aisle-3-image-final.s3.eu-west-2.amazo...
# ...                                                   ...
# 215424  https://aisle-3-image-final.s3.eu-west-2.amazo...
# 215425  https://aisle-3-image-final.s3.eu-west-2.amazo...
# 215426  https://aisle-3-image-final.s3.eu-west-2.amazo...
# 215427  https://aisle-3-image-final.s3.eu-west-2.amazo...
# 215428  https://aisle-3-image-final.s3.eu-west-2.amazo...
#
#                                                     image          pose  \
# 0       s3://aisle-3-image-final/images/original/allso...     side_shot
# 1       s3://aisle-3-image-final/images/original/allso...     side_shot
# 2       s3://aisle-3-image-final/images/original/allso...     side_shot
# 3       s3://aisle-3-image-final/images/original/allso...    upper_shot
# 4       s3://aisle-3-image-final/images/original/allso...  partial_shot
# ...                                                   ...           ...
# 215424  s3://aisle-3-image-final/images/original/ssens...  partial_shot
# 215425  s3://aisle-3-image-final/images/original/ssens...     pair_shot
# 215426  s3://aisle-3-image-final/images/original/ssens...     side_shot
# 215427  s3://aisle-3-image-final/images/original/ssens...     pair_shot
# 215428  s3://aisle-3-image-final/images/original/ssens...     pair_shot
#
#        color_pred
# 0           black
# 1           black
# 2           black
# 3           black
# 4           black
# ...           ...
# 215424     maroon
# 215425      white
# 215426      white
# 215427      beige
# 215428     maroon
#
# [215429 rows x 12 columns]

# %%
df.image = df.image.str.replace("s3://", "") + ".jpg"
df.image
# Out:
# 0         aisle-3-image-final/images/original/allsole/al...
# 1         aisle-3-image-final/images/original/allsole/al...
# 2         aisle-3-image-final/images/original/allsole/al...
# 3         aisle-3-image-final/images/original/allsole/al...
# 4         aisle-3-image-final/images/original/allsole/al...
#                                 ...
# 215424    aisle-3-image-final/images/original/ssense/sse...
# 215425    aisle-3-image-final/images/original/ssense/sse...
# 215426    aisle-3-image-final/images/original/ssense/sse...
# 215427    aisle-3-image-final/images/original/ssense/sse...
# 215428    aisle-3-image-final/images/original/ssense/sse...
# Name: image, Length: 215429, dtype: object

# %%
(data_dir + df.image).apply(os.path.isfile).value_counts()
# Out:
# True    215429
# Name: image, dtype: int64

# %%
# %%sql result <<
# SELECT
#     `source`,
#     `target`,
#     `match`
# FROM gold_annotations
# Out:
# 1190 rows affected.
# Returning data to local variable result

# %%
annotations = result.DataFrame()

# %%
annotations.match.value_counts()
# Out:
# 0    797
# 1    393
# Name: match, dtype: int64

# %%
print(
    "ids in annotations not in main:",
    len(np.setdiff1d(np.union1d(annotations.source, annotations.target), df.id)),
)
# Out:
# ids in annotations not in main: 0

# %%
G = nx.Graph()
G.add_nodes_from(np.union1d(annotations.source, annotations.target))
G.add_edges_from(annotations.loc[annotations.match == 1, ["source", "target"]].values)
print(
    f"Number of nodes: {G.number_of_nodes()} | Number of edges: {G.number_of_edges()}"
)
clusters = sorted(nx.connected_components(G), key=len, reverse=True)
pd.Series(clusters).apply(len).value_counts().sort_index()
# Out:
# Number of nodes: 655 | Number of edges: 393
# 1    116
# 2    198
# 3     25
# 4     11
# 5      3
# 9      1
# dtype: int64

# %%
def loc(frame, idx, col):
    result = frame.loc[idx, col]
    if isinstance(result, pd.Series):
        result = result.iloc[0]
    return result

# %%
ground_truth = defaultdict(list)
for cluster in clusters:
    for anchor in cluster:
        matches = cluster.copy()
        for col in ["brand", "gender"]:
            matches = [match for match in matches if loc(df, match, col) == loc(df, anchor, col)]
        for col in ["merchant"]:
            matches = [match for match in matches if loc(df, match, col) != loc(df, anchor, col)]
        ground_truth[anchor] = [anchor] + matches
len(ground_truth)
# Out:
# 655

# %%
df["ground_truth"] = df.id.map(ground_truth)
df
# Out:
#                                         id            variant_id  \
# id
# allsole.10491511          allsole.10491511      allsole.10491633
# allsole.10491511          allsole.10491511      allsole.10491633
# allsole.10491511          allsole.10491511      allsole.10491633
# allsole.10491511          allsole.10491511      allsole.10491633
# allsole.10491511          allsole.10491511      allsole.10491633
# ...                                    ...                   ...
# ssense.221903M237021  ssense.221903M237021  ssense.221903M237021
# ssense.221903M237021  ssense.221903M237021  ssense.221903M237021
# ssense.221903M237021  ssense.221903M237021  ssense.221903M237021
# ssense.221903M237021  ssense.221903M237021  ssense.221903M237021
# ssense.221903M237021  ssense.221903M237021  ssense.221903M237021
#
#                                                                 title  \
# id
# allsole.10491511                       Vans Authentic Canvas Trainers
# allsole.10491511                       Vans Authentic Canvas Trainers
# allsole.10491511                       Vans Authentic Canvas Trainers
# allsole.10491511                       Vans Authentic Canvas Trainers
# allsole.10491511                       Vans Authentic Canvas Trainers
# ...                                                               ...
# ssense.221903M237021  Coach 1941 Black & Off-White Logo Slide Sandals
# ssense.221903M237021  Coach 1941 Black & Off-White Logo Slide Sandals
# ssense.221903M237021  Coach 1941 Black & Off-White Logo Slide Sandals
# ssense.221903M237021  Coach 1941 Black & Off-White Logo Slide Sandals
# ssense.221903M237021  Coach 1941 Black & Off-White Logo Slide Sandals
#
#                      merchant  brand  gender        color    imid  \
# id
# allsole.10491511      allsole   vans  unisex        Black       0
# allsole.10491511      allsole   vans  unisex        Black       1
# allsole.10491511      allsole   vans  unisex        Black       2
# allsole.10491511      allsole   vans  unisex        Black       3
# allsole.10491511      allsole   vans  unisex        Black       4
# ...                       ...    ...     ...          ...     ...
# ssense.221903M237021   ssense  coach     men  Chalk black  215424
# ssense.221903M237021   ssense  coach     men  Chalk black  215425
# ssense.221903M237021   ssense  coach     men  Chalk black  215426
# ssense.221903M237021   ssense  coach     men  Chalk black  215427
# ssense.221903M237021   ssense  coach     men  Chalk black  215428
#
#                                                               image_url  \
# id
# allsole.10491511      https://aisle-3-image-final.s3.eu-west-2.amazo...
# allsole.10491511      https://aisle-3-image-final.s3.eu-west-2.amazo...
# allsole.10491511      https://aisle-3-image-final.s3.eu-west-2.amazo...
# allsole.10491511      https://aisle-3-image-final.s3.eu-west-2.amazo...
# allsole.10491511      https://aisle-3-image-final.s3.eu-west-2.amazo...
# ...                                                                 ...
# ssense.221903M237021  https://aisle-3-image-final.s3.eu-west-2.amazo...
# ssense.221903M237021  https://aisle-3-image-final.s3.eu-west-2.amazo...
# ssense.221903M237021  https://aisle-3-image-final.s3.eu-west-2.amazo...
# ssense.221903M237021  https://aisle-3-image-final.s3.eu-west-2.amazo...
# ssense.221903M237021  https://aisle-3-image-final.s3.eu-west-2.amazo...
#
#                                                                   image  \
# id
# allsole.10491511      aisle-3-image-final/images/original/allsole/al...
# allsole.10491511      aisle-3-image-final/images/original/allsole/al...
# allsole.10491511      aisle-3-image-final/images/original/allsole/al...
# allsole.10491511      aisle-3-image-final/images/original/allsole/al...
# allsole.10491511      aisle-3-image-final/images/original/allsole/al...
# ...                                                                 ...
# ssense.221903M237021  aisle-3-image-final/images/original/ssense/sse...
# ssense.221903M237021  aisle-3-image-final/images/original/ssense/sse...
# ssense.221903M237021  aisle-3-image-final/images/original/ssense/sse...
# ssense.221903M237021  aisle-3-image-final/images/original/ssense/sse...
# ssense.221903M237021  aisle-3-image-final/images/original/ssense/sse...
#
#                               pose color_pred ground_truth
# id
# allsole.10491511         side_shot      black           []
# allsole.10491511         side_shot      black           []
# allsole.10491511         side_shot      black           []
# allsole.10491511        upper_shot      black           []
# allsole.10491511      partial_shot      black           []
# ...                            ...        ...          ...
# ssense.221903M237021  partial_shot     maroon           []
# ssense.221903M237021     pair_shot      white           []
# ssense.221903M237021     side_shot      white           []
# ssense.221903M237021     pair_shot      beige           []
# ssense.221903M237021     pair_shot     maroon           []
#
# [215429 rows x 13 columns]

# %%
df.set_index("id", drop=False, inplace=True)
df.imid = range(len(df))

# %%
def viz(
    frame: pd.DataFrame,
    image_size: int = 200,
    max_images: int = None,
    **kwargs: Dict[str, List[Any]],
) -> None:
    frame = frame.reset_index(drop=True)

    extra_df = None
    if len(kwargs):
        extra_df = pd.DataFrame(kwargs)
        assert len(extra_df) == len(frame), "kwargs must have same length as frame"
        for col in extra_df.columns:
            extra_df[col] = f"{col} : " + extra_df[col].astype(str)

    html = iplt.plot_images(
        frame.image_url,
        labels=frame.id,
        custom_texts="<HR>"
        + (
            ""
            if extra_df is None
            else ("<HR>" + extra_df.apply(" <br> ".join, axis=1) + "<HR><HR>")
        )
        + frame.title
        + "<HR>"
        + frame[["merchant", "brand", "gender", "color"]].apply(" <br> ".join, axis=1),
        img_width=image_size,
        show_url=False,
        max_images=max_images if max_images else len(frame),
    )


viz(df.tail(4), dist=np.linspace(0.1, 0.9, 4))
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-dLPif8ZW6bSfZup83xZnpC {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-dLPif8ZW6bSfZup83xZnpC {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-dLPif8ZW6bSfZup83xZnpC {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-dLPif8ZW6bSfZup83xZnpC:checked ~ #ipyplot-html-viewer-textarea-dLPif8ZW6bSfZup83xZnpC {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-dLPif8ZW6bSfZup83xZnpC:checked + #ipyplot-html-viewer-label-dLPif8ZW6bSfZup83xZnpC:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-dLPif8ZW6bSfZup83xZnpC">
#         <label id="ipyplot-html-viewer-label-dLPif8ZW6bSfZup83xZnpC" for="ipyplot-html-viewer-toggle-dLPif8ZW6bSfZup83xZnpC">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-dLPif8ZW6bSfZup83xZnpC" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-LYREMu6LeLVGvxxspAAsPG {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-LYREMu6LeLVGvxxspAAsPG {
#             width: 200px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-LYREMu6LeLVGvxxspAAsPG {
#             width: 200px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-LYREMu6LeLVGvxxspAAsPG span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-LYREMu6LeLVGvxxspAAsPG span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-LYREMu6LeLVGvxxspAAsPG img {
#             width: 200px;
#         }
#
#         div.ipyplot-content-div-LYREMu6LeLVGvxxspAAsPG span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-LYREMu6LeLVGvxxspAAsPG span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-LYREMu6LeLVGvxxspAAsPG]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-LYREMu6LeLVGvxxspAAsPG]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-LYREMu6LeLVGvxxspAAsPG]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-LYREMu6LeLVGvxxspAAsPG">
#     <div class="ipyplot-placeholder-div-LYREMu6LeLVGvxxspAAsPG">
#         <div id="ipyplot-content-div-LYREMu6LeLVGvxxspAAsPG-8aKaCua5GScdBgf6wCvaUs" class="ipyplot-content-div-LYREMu6LeLVGvxxspAAsPG">
#             <h4 style="font-size: 12px; word-wrap: break-word;">ssense.221903M237021</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;"><HR><HR>dist : 0.1<HR><HR>Coach 1941 Black & Off-White Logo Slide Sandals<HR>ssense <br> coach <br> men <br> Chalk black</h4><img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/ssense/ssense.221903M237021/6892ae29-7352-3ea8-a88f-4d894637288b"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-LYREMu6LeLVGvxxspAAsPG-8aKaCua5GScdBgf6wCvaUs">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-LYREMu6LeLVGvxxspAAsPG">
#         <div id="ipyplot-content-div-LYREMu6LeLVGvxxspAAsPG-MnwHsGEQ7ZsoNgTHPo4J2Q" class="ipyplot-content-div-LYREMu6LeLVGvxxspAAsPG">
#             <h4 style="font-size: 12px; word-wrap: break-word;">ssense.221903M237021</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;"><HR><HR>dist : 0.3666666666666667<HR><HR>Coach 1941 Black & Off-White Logo Slide Sandals<HR>ssense <br> coach <br> men <br> Chalk black</h4><img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/ssense/ssense.221903M237021/a3b68c1c-bb9b-36f2-8f63-e8c1b3093981"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-LYREMu6LeLVGvxxspAAsPG-MnwHsGEQ7ZsoNgTHPo4J2Q">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-LYREMu6LeLVGvxxspAAsPG">
#         <div id="ipyplot-content-div-LYREMu6LeLVGvxxspAAsPG-hfXETUNawYmg4PZETikgrZ" class="ipyplot-content-div-LYREMu6LeLVGvxxspAAsPG">
#             <h4 style="font-size: 12px; word-wrap: break-word;">ssense.221903M237021</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;"><HR><HR>dist : 0.6333333333333333<HR><HR>Coach 1941 Black & Off-White Logo Slide Sandals<HR>ssense <br> coach <br> men <br> Chalk black</h4><img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/ssense/ssense.221903M237021/efcef461-e477-328b-a4c5-eda94b6f37ea"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-LYREMu6LeLVGvxxspAAsPG-hfXETUNawYmg4PZETikgrZ">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-LYREMu6LeLVGvxxspAAsPG">
#         <div id="ipyplot-content-div-LYREMu6LeLVGvxxspAAsPG-ihmQULx5f6N5XxNtYnwGrb" class="ipyplot-content-div-LYREMu6LeLVGvxxspAAsPG">
#             <h4 style="font-size: 12px; word-wrap: break-word;">ssense.221903M237021</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;"><HR><HR>dist : 0.9<HR><HR>Coach 1941 Black & Off-White Logo Slide Sandals<HR>ssense <br> coach <br> men <br> Chalk black</h4><img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/ssense/ssense.221903M237021/656e0fe1-ab9f-3561-8a86-f296e62514ac"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-LYREMu6LeLVGvxxspAAsPG-ihmQULx5f6N5XxNtYnwGrb">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-LYREMu6LeLVGvxxspAAsPG {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-LYREMu6LeLVGvxxspAAsPG {
#             width: 200px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-LYREMu6LeLVGvxxspAAsPG {
#             width: 200px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-LYREMu6LeLVGvxxspAAsPG span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-LYREMu6LeLVGvxxspAAsPG span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-LYREMu6LeLVGvxxspAAsPG img {
#             width: 200px;
#         }
#
#         div.ipyplot-content-div-LYREMu6LeLVGvxxspAAsPG span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-LYREMu6LeLVGvxxspAAsPG span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-LYREMu6LeLVGvxxspAAsPG]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-LYREMu6LeLVGvxxspAAsPG]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-LYREMu6LeLVGvxxspAAsPG]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-LYREMu6LeLVGvxxspAAsPG">
#     <div class="ipyplot-placeholder-div-LYREMu6LeLVGvxxspAAsPG">
#         <div id="ipyplot-content-div-LYREMu6LeLVGvxxspAAsPG-8aKaCua5GScdBgf6wCvaUs" class="ipyplot-content-div-LYREMu6LeLVGvxxspAAsPG">
#             <h4 style="font-size: 12px; word-wrap: break-word;">ssense.221903M237021</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;"><HR><HR>dist : 0.1<HR><HR>Coach 1941 Black & Off-White Logo Slide Sandals<HR>ssense <br> coach <br> men <br> Chalk black</h4><img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/ssense/ssense.221903M237021/6892ae29-7352-3ea8-a88f-4d894637288b"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-LYREMu6LeLVGvxxspAAsPG-8aKaCua5GScdBgf6wCvaUs">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-LYREMu6LeLVGvxxspAAsPG">
#         <div id="ipyplot-content-div-LYREMu6LeLVGvxxspAAsPG-MnwHsGEQ7ZsoNgTHPo4J2Q" class="ipyplot-content-div-LYREMu6LeLVGvxxspAAsPG">
#             <h4 style="font-size: 12px; word-wrap: break-word;">ssense.221903M237021</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;"><HR><HR>dist : 0.3666666666666667<HR><HR>Coach 1941 Black & Off-White Logo Slide Sandals<HR>ssense <br> coach <br> men <br> Chalk black</h4><img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/ssense/ssense.221903M237021/a3b68c1c-bb9b-36f2-8f63-e8c1b3093981"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-LYREMu6LeLVGvxxspAAsPG-MnwHsGEQ7ZsoNgTHPo4J2Q">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-LYREMu6LeLVGvxxspAAsPG">
#         <div id="ipyplot-content-div-LYREMu6LeLVGvxxspAAsPG-hfXETUNawYmg4PZETikgrZ" class="ipyplot-content-div-LYREMu6LeLVGvxxspAAsPG">
#             <h4 style="font-size: 12px; word-wrap: break-word;">ssense.221903M237021</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;"><HR><HR>dist : 0.6333333333333333<HR><HR>Coach 1941 Black & Off-White Logo Slide Sandals<HR>ssense <br> coach <br> men <br> Chalk black</h4><img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/ssense/ssense.221903M237021/efcef461-e477-328b-a4c5-eda94b6f37ea"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-LYREMu6LeLVGvxxspAAsPG-hfXETUNawYmg4PZETikgrZ">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-LYREMu6LeLVGvxxspAAsPG">
#         <div id="ipyplot-content-div-LYREMu6LeLVGvxxspAAsPG-ihmQULx5f6N5XxNtYnwGrb" class="ipyplot-content-div-LYREMu6LeLVGvxxspAAsPG">
#             <h4 style="font-size: 12px; word-wrap: break-word;">ssense.221903M237021</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;"><HR><HR>dist : 0.9<HR><HR>Coach 1941 Black & Off-White Logo Slide Sandals<HR>ssense <br> coach <br> men <br> Chalk black</h4><img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/ssense/ssense.221903M237021/656e0fe1-ab9f-3561-8a86-f296e62514ac"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-LYREMu6LeLVGvxxspAAsPG-ihmQULx5f6N5XxNtYnwGrb">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>

# %%
def compute_scores(pred, gt):
    tp = len(np.intersect1d(pred, gt))
    iou = tp / len(np.union1d(pred, gt))
    # fp = np.setdiff1d(pred, gt)
    if tp == 0:
        prec, recall, f1 = (0.0, 0.0, 0.0)
    else:
        prec = tp / len(pred)
        recall = tp / len(gt)
        f1 = (2 * prec * recall) / (prec + recall)
    return {"iou": iou, "prec": prec, "recall": recall, "f1": f1}


def get_nn_imgs(imids, k=50, threshold=None):
    if isinstance(imids, int):
        imids = [imids]
    qx = features[imids]
    D, I = index.search(qx, k=k)
    if threshold is None:
        threshold = D.max()
    mask = np.argwhere(np.logical_and(I != -1, D < threshold))
    nns = list()
    for i, nn in itertools.groupby(mask, lambda x: x[0]):
        nn = np.vstack(list(nn))
        nns.append(
            [
                (idx, dist)
                for idx, dist in zip(
                    I[nn[:, 0], nn[:, 1]].tolist(), D[nn[:, 0], nn[:, 1]].tolist()
                )
            ]
        )
    return nns


def perform_blocking(nns, block_on=["gender", "brand"], block_off=["merchant"]):
    if len(nns) > 1:
        q_imid = nns[0][0]
        query = df.iloc[q_imid]
        for col in block_on:
            nns = [nn for nn in nns if query[col] == df.iloc[nn[0]][col]]
        if len(block_off):
            for col in block_off:
                nns = [nn for nn in nns if query[col] != df.iloc[nn[0]][col]]
        nns = [(q_imid, 0.0)] + nns
    return nns


def imids_to_id(imids):
    return df.iloc[imids, 0].unique()


def id_to_imids(ids):
    imids = df.loc[ids, "imid"]
    if isinstance(imids, int):
        return [imids]
    return imids


def apply_threshold(nns, threshold=0.5, similarity=False):
    return [nn[0] for nn in nns if nn[1] < threshold]

# %%
features = np.load("ld_features.npy")
features.shape
# Out:
# (215429, 512)

# %%
index = faiss.IndexFlatL2(features.shape[1])
index.add(features)
index.ntotal
# Out:
# 215429

# %% [markdown]
# # Analyze popular products

# %%
pred_df = pd.read_csv("../../notes/popular.csv")
pred_df
# Out:
#            brand                   title gender  \
# 0           Nike     Air Max 270 Trainer    men
# 1           Nike  Air Max 90 LTR Trainer    men
# 2           Nike  Air Max 90 LTR Trainer    men
# 3           Nike  Air Max 90 LTR Trainer    men
# 4           Nike  Air Max 90 LTR Trainer    men
# ..           ...                     ...    ...
# 156  New Balance           57/40 Trainer    men
# 157  New Balance           57/40 Trainer    men
# 158  New Balance           57/40 Trainer    men
# 159  New Balance           57/40 Trainer    men
# 160  New Balance           57/40 Trainer    men
#
#                            master_product                 offer_id
# 0    f45773a1-0dd3-4f16-a5ac-70dcaa45882b  footlocker.314212239504
# 1    230286c1-0000-4472-930f-8a9a0057e235     footasylum.CZ5594100
# 2    10a1fd88-1eea-4c6b-88a2-53f6ac1a3add  footlocker.314206402704
# 3    10a1fd88-1eea-4c6b-88a2-53f6ac1a3add             asos.1666471
# 4    34303c91-eb38-4a2f-91f8-4d0a785251cb     footasylum.CN8490001
# ..                                    ...                      ...
# 156  5138bd9d-adf0-4b70-84a1-214adbee1d64   endclothing.3087649156
# 157  5138bd9d-adf0-4b70-84a1-214adbee1d64      footasylum.M5740SB1
# 158  5138bd9d-adf0-4b70-84a1-214adbee1d64         schuh.3403301150
# 159  5138bd9d-adf0-4b70-84a1-214adbee1d64  footlocker.314214787104
# 160  5138bd9d-adf0-4b70-84a1-214adbee1d64      newbalance.M5740SB1
#
# [161 rows x 5 columns]

# %%
pred_df.offer_id.isin(df.index).value_counts()
# Out:
# True    161
# Name: offer_id, dtype: int64

# %%
viz(df.loc[set(pred_df.offer_id)].drop_duplicates("id"))
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-QapZV5gheRmn9nFKredpXc {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-QapZV5gheRmn9nFKredpXc {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-QapZV5gheRmn9nFKredpXc {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-QapZV5gheRmn9nFKredpXc:checked ~ #ipyplot-html-viewer-textarea-QapZV5gheRmn9nFKredpXc {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-QapZV5gheRmn9nFKredpXc:checked + #ipyplot-html-viewer-label-QapZV5gheRmn9nFKredpXc:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-QapZV5gheRmn9nFKredpXc">
#         <label id="ipyplot-html-viewer-label-QapZV5gheRmn9nFKredpXc" for="ipyplot-html-viewer-toggle-QapZV5gheRmn9nFKredpXc">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-QapZV5gheRmn9nFKredpXc" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-ahTsoEXhXYaTMDvFa9body {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-ahTsoEXhXYaTMDvFa9body {
#             width: 200px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-ahTsoEXhXYaTMDvFa9body {
#             width: 200px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-ahTsoEXhXYaTMDvFa9body span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-ahTsoEXhXYaTMDvFa9body span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-ahTsoEXhXYaTMDvFa9body img {
#             width: 200px;
#         }
#
#         div.ipyplot-content-div-ahTsoEXhXYaTMDvFa9body span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-ahTsoEXhXYaTMDvFa9body span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-ahTsoEXhXYaTMDvFa9body]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-ahTsoEXhXYaTMDvFa9body]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-ahTsoEXhXYaTMDvFa9body]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-ahTsoEXhXYaTMDvFa9body">
#     <div class="ipyplot-placeholder-div-ahTsoEXhXYaTMDvFa9body">
#         <div id="ipyplot-content-div-ahTsoEXhXYaTMDvFa9body-iWHCsorQB3tBmSMBomSR7f" class="ipyplot-content-div-ahTsoEXhXYaTMDvFa9body">
#             <h4 style="font-size: 12px; word-wrap: break-word;">newbalance.MS237HG1</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;"><HR>New Balance 237<HR>new balance -- new balance -- men -- Multicolour</h4><img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/newbalance/newbalance.MS237HG1/fedb479c-51a5-3c5b-a551-e5a3414a9ce8"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ahTsoEXhXYaTMDvFa9body-iWHCsorQB3tBmSMBomSR7f">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-ahTsoEXhXYaTMDvFa9body">
#         <div id="ipyplot-content-div-ahTsoEXhXYaTMDvFa9body-ZwmHkRGSkpYNka3xt7tvFT" class="ipyplot-content-div-ahTsoEXhXYaTMDvFa9body">
#             <h4 style="font-size: 12px; word-wrap: break-word;">endclothing.3087649156</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;"><HR>New Balance M5740SB1<HR>end clothing -- new balance -- men -- Sea salt & purple</h4><img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/endclothing/endclothing.3087649156/5bcf4b39-c8c4-3ac0-ad59-93c65474d9cc"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ahTsoEXhXYaTMDvFa9body-ZwmHkRGSkpYNka3xt7tvFT">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-ahTsoEXhXYaTMDvFa9body">
#         <div id="ipyplot-content-div-ahTsoEXhXYaTMDvFa9body-4Y4aYBkyAdriE3YNrz3ihn" class="ipyplot-content-div-ahTsoEXhXYaTMDvFa9body">
#             <h4 style="font-size: 12px; word-wrap: break-word;">endclothing.3087629364</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;"><HR>Adidas Ozweego<HR>end clothing -- adidas -- men -- Core black</h4><img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/endclothing/endclothing.3087629364/af93d40f-5d18-335e-ba20-02437527e187"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ahTsoEXhXYaTMDvFa9body-4Y4aYBkyAdriE3YNrz3ihn">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-ahTsoEXhXYaTMDvFa9body">
#         <div id="ipyplot-content-div-ahTsoEXhXYaTMDvFa9body-AVcZZHwzfL8j5asSbm6H5t" class="ipyplot-content-div-ahTsoEXhXYaTMDvFa9body">
#             <h4 style="font-size: 12px; word-wrap: break-word;">footasylum.38081003</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;"><HR>Caven Trainers<HR>footasylum -- puma -- men -- Black</h4><img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/footasylum/footasylum.38081003/cc8793b9-725a-30a6-8526-657a5cd3640e"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ahTsoEXhXYaTMDvFa9body-AVcZZHwzfL8j5asSbm6H5t">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-ahTsoEXhXYaTMDvFa9body">
#         <div id="ipyplot-content-div-ahTsoEXhXYaTMDvFa9body-iScCmiXN3k3eW4RLzZ3NNm" class="ipyplot-content-div-ahTsoEXhXYaTMDvFa9body">
#             <h4 style="font-size: 12px; word-wrap: break-word;">sportsdirect.12101202270</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;"><HR>Puma Anzarun Trainers<HR>sportsdirect -- puma -- men -- Multicolour</h4><img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/sportsdirect/sportsdirect.12101202270/928feadf-4474-3e4d-a70c-c0fe01111836"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ahTsoEXhXYaTMDvFa9body-iScCmiXN3k3eW4RLzZ3NNm">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-ahTs
#         <style>
#         #ipyplot-imgs-container-div-ahTsoEXhXYaTMDvFa9body {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-ahTsoEXhXYaTMDvFa9body {
#             width: 200px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-ahTsoEXhXYaTMDvFa9body {
#             width: 200px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-ahTsoEXhXYaTMDvFa9body span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-ahTsoEXhXYaTMDvFa9body span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-ahTsoEXhXYaTMDvFa9body img {
#             width: 200px;
#         }
#
#         div.ipyplot-content-div-ahTsoEXhXYaTMDvFa9body span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-ahTsoEXhXYaTMDvFa9body span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-ahTsoEXhXYaTMDvFa9body]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-ahTsoEXhXYaTMDvFa9body]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-ahTsoEXhXYaTMDvFa9body]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-ahTsoEXhXYaTMDvFa9body">
#     <div class="ipyplot-placeholder-div-ahTsoEXhXYaTMDvFa9body">
#         <div id="ipyplot-content-div-ahTsoEXhXYaTMDvFa9body-iWHCsorQB3tBmSMBomSR7f" class="ipyplot-content-div-ahTsoEXhXYaTMDvFa9body">
#             <h4 style="font-size: 12px; word-wrap: break-word;">newbalance.MS237HG1</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;"><HR>New Balance 237<HR>new balance -- new balance -- men -- Multicolour</h4><img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/newbalance/newbalance.MS237HG1/fedb479c-51a5-3c5b-a551-e5a3414a9ce8"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ahTsoEXhXYaTMDvFa9body-iWHCsorQB3tBmSMBomSR7f">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-ahTsoEXhXYaTMDvFa9body">
#         <div id="ipyplot-content-div-ahTsoEXhXYaTMDvFa9body-ZwmHkRGSkpYNka3xt7tvFT" class="ipyplot-content-div-ahTsoEXhXYaTMDvFa9body">
#             <h4 style="font-size: 12px; word-wrap: break-word;">endclothing.3087649156</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;"><HR>New Balance M5740SB1<HR>end clothing -- new balance -- men -- Sea salt & purple</h4><img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/endclothing/endclothing.3087649156/5bcf4b39-c8c4-3ac0-ad59-93c65474d9cc"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ahTsoEXhXYaTMDvFa9body-ZwmHkRGSkpYNka3xt7tvFT">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-ahTsoEXhXYaTMDvFa9body">
#         <div id="ipyplot-content-div-ahTsoEXhXYaTMDvFa9body-4Y4aYBkyAdriE3YNrz3ihn" class="ipyplot-content-div-ahTsoEXhXYaTMDvFa9body">
#             <h4 style="font-size: 12px; word-wrap: break-word;">endclothing.3087629364</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;"><HR>Adidas Ozweego<HR>end clothing -- adidas -- men -- Core black</h4><img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/endclothing/endclothing.3087629364/af93d40f-5d18-335e-ba20-02437527e187"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ahTsoEXhXYaTMDvFa9body-4Y4aYBkyAdriE3YNrz3ihn">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-ahTsoEXhXYaTMDvFa9body">
#         <div id="ipyplot-content-div-ahTsoEXhXYaTMDvFa9body-AVcZZHwzfL8j5asSbm6H5t" class="ipyplot-content-div-ahTsoEXhXYaTMDvFa9body">
#             <h4 style="font-size: 12px; word-wrap: break-word;">footasylum.38081003</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;"><HR>Caven Trainers<HR>footasylum -- puma -- men -- Black</h4><img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/footasylum/footasylum.38081003/cc8793b9-725a-30a6-8526-657a5cd3640e"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ahTsoEXhXYaTMDvFa9body-AVcZZHwzfL8j5asSbm6H5t">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-ahTsoEXhXYaTMDvFa9body">
#         <div id="ipyplot-content-div-ahTsoEXhXYaTMDvFa9body-iScCmiXN3k3eW4RLzZ3NNm" class="ipyplot-content-div-ahTsoEXhXYaTMDvFa9body">
#             <h4 style="font-size: 12px; word-wrap: break-word;">sportsdirect.12101202270</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;"><HR>Puma Anzarun Trainers<HR>sportsdirect -- puma -- men -- Multicolour</h4><img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/sportsdirect/sportsdirect.12101202270/928feadf-4474-3e4d-a70c-c0fe01111836"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ahTsoEXhXYaTMDvFa9body-iScCmiXN3k3eW4RLzZ3NNm">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-ahTsoEXhXYaTMDvFa9body">
#         <div id="ipyplot-content-div-ahTsoEXhXYaTMDvFa9body-Cd49ALTqzgrc9fUQKo2CR2" class="ipyplot-content-div-ahTsoEXhXYaTMDvFa9body">
#             <h4 style="font-size: 12px; word-wrap: break-word;">scotts.16189682</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;"><HR>adidas Originals Hamburg Trainers<HR>scotts -- adidas originals -- men -- Blue</h4><img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/scotts/scotts.16189682/50a960c8-e149-330f-a1cc-e7abb87cd406"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ahTsoEXhXYaTMDvFa9body-Cd49ALTqzgrc9fUQKo2CR2">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-ahTsoEXhXYaTMDvFa9body">
#         <div id="ipyplot-content-div-ahTsoEXhXYaTMDvFa9body-KVKU2Byo742jY5j4odZXhu" class="ipyplot-content-div-ahTsoEXhXYaTMDvFa9body">
#             <h4 style="font-size: 12px; word-wrap: break-word;">footasylum.ML574BA2</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;"><HR>574 'History Class' Trainers<HR>footasylum -- new balance -- men -- Multicolour</h4><img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/footasylum/footasylum.ML574BA2/259d47ea-02bc-3fc5-86cb-94c7f57d1f80"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ahTsoEXhXYaTMDvFa9body-KVKU

# %%
pred_imids = pred_df.groupby("offer_id").offer_id.apply(id_to_imids).values
print("pred_imids", len(pred_imids))

# get nns with dists
print("peforming index search")
t = time.perf_counter()
nns = get_nn_imgs(pred_imids, k=100)
print("time to search:", time.perf_counter() - t)

# blocking
print("peforming blocking")
t = time.perf_counter()
nns = [perform_blocking(nn) for nn in nns]
print("time to perform blocking:", time.perf_counter() - t)

nns = dict(zip(pred_imids, nns))
len(nns)
# Out:
# pred_imids 867
# peforming index search
# time to search: 4.1847757779996755
# peforming blocking
# time to perform blocking: 8.262133067999457
# 867

# %%
df.pose.value_counts()
# Out:
# pair_shot          59832
# side_shot          54196
# partial_shot       31670
# human_wear_shot    23285
# upper_shot         12811
# 3qrt_shot          12510
# sole_shot          11058
# heel_shot           8256
# non_available       1811
# Name: pose, dtype: int64

# %%
df.loc[pred_df.offer_id.unique()].pose.value_counts()
# Out:
# pair_shot          368
# side_shot          264
# partial_shot       102
# sole_shot           92
# human_wear_shot     20
# non_available        7
# 3qrt_shot            6
# heel_shot            4
# upper_shot           4
# Name: pose, dtype: int64

# %%
df.loc[pred_df.offer_id.unique()].reset_index(drop=True).groupby("id").pose.value_counts()
# Out:
# id                        pose
# asos.104728610            partial_shot       3
#                           pair_shot          1
# asos.110858489            partial_shot       3
#                           human_wear_shot    1
# asos.1151505              pair_shot          3
#                                             ..
# sportsdirect.12101202270  side_shot          2
#                           sole_shot          1
# sportsdirect.16102901270  pair_shot          3
#                           side_shot          2
#                           sole_shot          1
# Name: pose, Length: 467, dtype: int64

# %%
df.iloc[nn_imids].pose
# Out:
# id
# footasylum.37310826         side_shot
# sportsdirect.12138402270    side_shot
# sportsdirect.12138402270    side_shot
# sportsdirect.12138402270    pair_shot
# Name: pose, dtype: object

# %%
for imid in random.choices(pred_imids, k=20):
    nn_images = nns[imid]
    nn_imids, nn_dists = map(list, zip(*nn_images))
    display(HTML(f"<h2>{df.iloc[imid].id}  |  Ground Truth : [ {', '.join(df.iloc[imid].ground_truth)} ]</h2>"))

    viz(
        df.iloc[nn_imids],
        dist=nn_dists,
        pose=df.iloc[nn_imids].pose.values,
        color=df.iloc[nn_imids].color_pred.values,
    )
    display(HTML("<HR>" * 3))
# Out:
# <h2>footasylum.BV9977100  |  Ground Truth : [  ]</h2>
#     <style>
#         #ipyplot-html-viewer-toggle-9hbhnVrVodXpmRt8sPWC2n {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-9hbhnVrVodXpmRt8sPWC2n {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-9hbhnVrVodXpmRt8sPWC2n {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-9hbhnVrVodXpmRt8sPWC2n:checked ~ #ipyplot-html-viewer-textarea-9hbhnVrVodXpmRt8sPWC2n {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-9hbhnVrVodXpmRt8sPWC2n:checked + #ipyplot-html-viewer-label-9hbhnVrVodXpmRt8sPWC2n:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-9hbhnVrVodXpmRt8sPWC2n">
#         <label id="ipyplot-html-viewer-label-9hbhnVrVodXpmRt8sPWC2n" for="ipyplot-html-viewer-toggle-9hbhnVrVodXpmRt8sPWC2n">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-9hbhnVrVodXpmRt8sPWC2n" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-nwgTsshK6orXinTv9bEyjR {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-nwgTsshK6orXinTv9bEyjR {
#             width: 200px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-nwgTsshK6orXinTv9bEyjR {
#             width: 200px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-nwgTsshK6orXinTv9bEyjR span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-nwgTsshK6orXinTv9bEyjR span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-nwgTsshK6orXinTv9bEyjR img {
#             width: 200px;
#         }
#
#         div.ipyplot-content-div-nwgTsshK6orXinTv9bEyjR span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-nwgTsshK6orXinTv9bEyjR span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-nwgTsshK6orXinTv9bEyjR]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-nwgTsshK6orXinTv9bEyjR]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-nwgTsshK6orXinTv9bEyjR]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-nwgTsshK6orXinTv9bEyjR">
#     <div class="ipyplot-placeholder-div-nwgTsshK6orXinTv9bEyjR">
#         <div id="ipyplot-content-div-nwgTsshK6orXinTv9bEyjR-YQiiWt5ErY43qPrEyvDncz" class="ipyplot-content-div-nwgTsshK6orXinTv9bEyjR">
#             <h4 style="font-size: 12px; word-wrap: break-word;">footasylum.BV9977100</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;"><HR><HR>dist : 0.0 <br> pose : side_shot <br> color : white<HR><HR>Air Max 2090 Trainers<HR>footasylum <br> nike <br> men <br> Multicolour</h4><img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/footasylum/footasylum.BV9977100/e56e754d-8ead-350b-95ac-6e9e8670b454"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-nwgTsshK6orXinTv9bEyjR-YQiiWt5ErY43qPrEyvDncz">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-nwgTsshK6orXinTv9bEyjR">
#         <div id="ipyplot-content-div-nwgTsshK6orXinTv9bEyjR-CcYoFh9sPmjY2K9zop7egw" class="ipyplot-content-div-nwgTsshK6orXinTv9bEyjR">
#             <h4 style="font-size: 12px; word-wrap: break-word;">footlocker.314207632804</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;"><HR><HR>dist : 0.6577243804931641 <br> pose : side_shot <br> color : white<HR><HR>Nike Air Max 2090<HR>foot locker <br> nike <br> men <br> White</h4><img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/footlocker/footlocker.314207632804/f4dcaa78-19be-397e-9fea-4e916f0931de"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-nwgTsshK6orXinTv9bEyjR-CcYoFh9sPmjY2K9zop7egw">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-nwgTsshK6orXinTv9bEyjR">
#         <div id="ipyplot-content-div-nwgTsshK6orXinTv9bEyjR-AUBKCLpt53rV3qmHvNCqhc" class="ipyplot-content-div-nwgTsshK6orXinTv9bEyjR">
#             <h4 style="font-size: 12px; word-wrap: break-word;">footlocker.314207632804</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;"><HR><HR>dist : 0.6687755584716797 <br> pose : side_shot <br> color : white<HR><HR>Nike Air Max 2090<HR>foot locker <br> nike <br> men <br> White</h4><img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/footlocker/footlocker.314207632804/aa503398-30ed-36a3-a491-f66c7eb2ffab"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-nwgTsshK6orXinTv9bEyjR-AUBKCLpt53rV3qmHvNCqhc">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-nwgTsshK6orXinTv9bEyjR">
#         <div id="ipyplot-content-div-nwgTsshK6orXinTv9bEyjR-YFseYqQdiyf2i49puLuASS" class="ipyplot-content-div-nwgTsshK6orXinTv9bEyjR">
#             <h4 style="font-size: 12px; word-wrap: break-word;">nike.14110564</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;"><HR><HR>dist : 0.7357883453369141 <br> pose : pair_shot <br> color : maroon<HR><HR>NikeCourt React Vapor NXT Hard-Court Tennis Shoes<HR>nike <br> nike <br> men <br> Grey</h4><img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/nike/nike.14110564/de930b06-9302-32ee-bd3a-98b85ecb753e"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-nwgTsshK6orXinTv9bEyjR-YFseYqQdiyf2i49puLuASS">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-nwgTsshK6orXinTv9bEyjR">
#         <div id="ipyplot-content-div-nwgTsshK6orXinTv9bEyjR
br> men <br> Multicolour</h4><img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/footasylum/footasylum.CV2220100/9496a7d8-27cb-346f-9276-995c7a568563"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-VkWpeEMUP2xDxsrdDUyW4G-PbijFW8YQ784k7o4YKSVob">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-VkWpeEMUP2xDxsrdDUyW4G">
#         <div id="ipyplot-content-div-VkWpeEMUP2xDxsrdDUyW4G-hoHBvVfEmeoSQPUNhwkgHZ" class="ipyplot-content-div-VkWpeEMUP2xDxsrdDUyW4G">
#             <h4 style="font-size: 12px; word-wrap: break-word;">spartoo.6821867</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;"><HR><HR>dist : 0.8
# <HR><HR><HR>
# <h2>footlocker.314214697204  |  Ground Truth : [  ]</h2>
#     <style>
#         #ipyplot-html-viewer-toggle-eFxG2dci9HsMeUL7qSkEHF {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-eFxG2dci9HsMeUL7qSkEHF {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-eFxG2dci9HsMeUL7qSkEHF {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-eFxG2dci9HsMeUL7qSkEHF:checked ~ #ipyplot-html-viewer-textarea-eFxG2dci9HsMeUL7qSkEHF {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-eFxG2dci9HsMeUL7qSkEHF:checked + #ipyplot-html-viewer-label-eFxG2dci9HsMeUL7qSkEHF:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-eFxG2dci9HsMeUL7qSkEHF">
#         <label id="ipyplot-html-viewer-label-eFxG2dci9HsMeUL7qSkEHF" for="ipyplot-html-viewer-toggle-eFxG2dci9HsMeUL7qSkEHF">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-eFxG2dci9HsMeUL7qSkEHF" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-KhjJLvTVi6rHAKTxB6wv5C {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-KhjJLvTVi6rHAKTxB6wv5C {
#             width: 200px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-KhjJLvTVi6rHAKTxB6wv5C {
#             width: 200px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-KhjJLvTVi6rHAKTxB6wv5C span.ipyplot-img-close {
# ...
#             <h4 style="font-size: 12px; word-wrap: break-word;"><HR><HR>dist : 0.8267440795898438 <br> pose : pair_shot <br> color : white<HR><HR>New Balance M5740LT<HR>end clothing <br> new balance <br> men <br> White</h4><img src="https://aisle-3-image-final.s3.eu-west-2.amaz
#         <style>
#         #ipyplot-imgs-container-div-SjYfKDi8BN3jpkmKFwR3Ap {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-SjYfKDi8BN3jpkmKFwR3Ap {
#             width: 200px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-SjYfKDi8BN3jpkmKFwR3Ap {
#             width: 200px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-SjYfKDi8BN3jpkmKFwR3Ap span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-SjYfKDi8BN3jpkmKFwR3Ap span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-SjYfKDi8BN3jpkmKFwR3Ap img {
#             width: 200px;
#         }
#
#         div.ipyplot-content-div-SjYfKDi8BN3jpkmKFwR3Ap span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-SjYfKDi8BN3jpkmKFwR3Ap span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-SjYfKDi8BN3jpkmKFwR3Ap]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-SjYfKDi8BN3jpkmKFwR3Ap]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-SjYfKDi8BN3jpkmKFwR3Ap]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-SjYfKDi8BN3jpkmKFwR3Ap">
#     <div class="ipyplot-placeholder-div-SjYfKDi8BN3jpkmKFwR3Ap">
#         <div id="ipyplot-content-div-SjYfKDi8BN3jpkmKFwR3Ap-Ke6VZhQrdNrnx7tCejeNPT" class="ipyplot-content-div-SjYfKDi8BN3jpkmKFwR3Ap">
#             <h4 style="font-size: 12px; word-wrap: break-word;">footasylum.M5740DC1</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;"><HR><HR>dist : 0.0 <br> pose : side_shot <br> color : blue<HR><HR>M5740 Trainers<HR>footasylum <br> new balance <br> men <br> Multicolour</h4><img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/footasylum/footasylum.M5740DC1/25318eaa-b13a-3bbb-9cf3-dce9a113825e"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-SjYfKDi8BN3jpkmKFwR3Ap-Ke6VZhQrdNrnx7tCejeNPT">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-SjYfKDi8BN3jpkmKFwR3Ap">
#         <div id="ipyplot-content-div-SjYfKDi8BN3jpkmKFwR3Ap-CQnPpG9sbp4g4Ev9QqCDa5" class="ipyplot-content-div-SjYfKDi8BN3jpkmKFwR3Ap">
#             <h4 style="font-size: 12px; word-wrap: break-word;">endclothing.3087654393</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;"><HR><HR>dist : 0.647047758102417 <br> pose : pair_shot <br> color : blue<HR><HR>New Balance M5740DC1<HR>end clothing <br> new balance <br> men <br> Multicolour</h4><img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/endclothing/endclothing.3087654393/ffd91231-51b5-38a8-8e76-13ba2aa4a1bc"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-SjYfKDi8BN3jpkmKFwR3Ap-CQnPpG9sbp4g4Ev9QqCDa5">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-SjYfKDi8BN3jpkmKFwR3Ap">
#         <div id="ipyplot-content-div-SjYfKDi8BN3jpkmKFwR3Ap-oErtTv8oatw6ThjERwmB8Q" class="ipyplot-content-div-SjYfKDi8BN3jpkmKFwR3Ap">
#             <h4 style="font-size: 12px; word-wrap: break-word;">newbalance.M5740SR</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;"><HR><HR>dist : 0.8202923536300659 <br> pose : side_shot <br> color : brown<HR><HR>New Balance Unisex STAUD 57/40<HR>new balance <br> new balance <br> men <br> Multicolour</h4><img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/newbalance/newbalance.M5740SR/89c860c8-0252-3b6f-9d98-8ca5e24baf6a"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-SjYfKDi8BN3jpkmKFwR3Ap-oErtTv8oatw6ThjERwmB8Q">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-SjYfKDi8BN3jpkmKFwR3Ap">
#         <div id="ipyplot-content-div-SjYfKDi8BN3jpkmKFwR3Ap-5xgJ46Uu8YEiMhjVMu8UAf" class="ipyplot-content-div-SjYfKDi8BN3jpkmKFwR3Ap">
#             <h4 style="font-size: 12px; word-wrap: break-word;">newbalance.NM272ORB</h4>
#             <h4 style="font-size: 12px; word-wrap: break-word;"><HR><HR>dist : 0.8250347375869751 <br> pose : side_shot <br> color : orange<HR><HR>New Balance NB NUMERIC 272<HR>new balance <br> new balance <br> men <br> Multicolour</h4><img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/newbalance/newbalance.NM272ORB/c2119192-cf28-3eb6-8634-1f96c190bbd2"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-SjYfKDi8BN3jpkmKFwR3Ap-5xgJ46Uu8YEiMhjVMu8UAf">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-SjYfKDi8BN3jpkmKFwR3Ap">
#         <div id="ipyplot-content-div-SjYfKDi8BN3jpkmKFwR3Ap