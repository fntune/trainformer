# %% [markdown]
# # Exploring Perceptual Hashing for image-deduplication and as a low-hanging fruit for product-matching
# This notebook demonstrates the use-case of perceptual hashing applied on images for the following potential benefits:
# - **Data de-duplication / cleaning**
#   Image dedup is impreative as a data preprocessing step for training image models
# - **Product-matching low hanging fruit**
#   Being able to identify duplicate images across merchants can serve as a low-hanging fruit for product-matching. Providing zero-error, free product-matches for a substanitally common occurence of finding visually identical product images across merchants.
# - **Preload human-labelling tasks**
#   Using this list of free zero-error matches to preload human-in-the-loop tasks for product-matching, absolving the human annotator of matching obvious matches when the offer pair has same images.
# - **Fair evaluation of the product-matching models**
#   Since an image-encoder model can be seen as just a glorified perceptual hashing function (even a randomly intialized model will match duplicate images), removing duplicate images in evaluation sets will help us in getting fairer performance metrics.
#
# ## Introduction
# Perceptual hashes tell whether two images look nearly identical. This is different from cryptographic hashing algorithms (like MD5, SHA-1) where tiny changes in the image give completely different hashes. In image fingerprinting, we actually want our similar inputs to have similar output hashes as well.
#
# For a much better explaination check [this blog](https://www.hackerfactor.com/blog/index.php?/archives/432-Looks-Like-It.html).
#
#
# ## Problem Statement
# The current data in our `offers_en` table has duplicates of the following kinds:
# - different offer id and/or different a3_prod_id; but same title, same color label.
# - different offer id and/or different a3_prod_id; slightly different title and color label but same offer.
# - offer with identical offer images for its gender variants
#
# Perceptual hashing is a great way to deal with this data cleaning problem but for its adaptiblity in our use-case there are certain challanges:
# - Phashing also hashes nearly identical images to the same hash output. This will lead to error-propogation and will cause variants of the offers to be matched together. This is usually a desired outcome of Phashing but in our case we do not want near identical image hashing.
# - Phashing in general is performed on grayscale images. This makes the Phashing algorithm invariant to color filters applied on images. This again is a desired behaviour of a Phashing algo but in our use-case we do not want indiffernce to colors since that would lead to color-variants being hashed together.
#
# ## Solution Statement
# In order for the Phashing to work for our use-case we need to modify the original phash algo for the following outcomes:
# - **Fast and cheap**
#   Popular phashing algos are all compute cheap and suitably belongs to lambda function.
# - **Should be robust against change in image resolution, aspect ratio, JPEG compression.**
#   This is a pre-fulfilled expectation with phashing as Phashing is robust to these kind of perturbations.
# - **Should not hash near-identical images as duplicates.**
#   This might be achieved by increasing the "resolution" of the hashing function.
# - **Should not be indifferent to color profiles of the same image.**
#   This might be achieved by modifying repeating the hashing logic over the 3 channels and appending the 3 hashes.

# %%
import os
import random
import glob
from collections import defaultdict
import pickle
import uuid

import numpy as np
import pandas as pd
import ipyplot as iplt

data_dir = "/data/"

# %% [markdown]
# # Fetch data

# %%
df = pd.read_parquet("s3://aisle3-ml-datasets/product-matching/aisle3/clean_poses.parquet")
df
# Out:
#                           id            variant_id  \
# 0           allsole.10491511      allsole.10491633
# 1           allsole.10491511      allsole.10491633
# 2           allsole.10491511      allsole.10491633
# 3           allsole.10491511      allsole.10491633
# 4           allsole.10491511      allsole.10491633
# ...                      ...                   ...
# 202555  ssense.221903M237021  ssense.221903M237021
# 202556  ssense.221903M237021  ssense.221903M237021
# 202557  ssense.221903M237021  ssense.221903M237021
# 202558  ssense.221903M237021  ssense.221903M237021
# 202559  ssense.221903M237021  ssense.221903M237021
#
#                                                   title merchant  brand  \
# 0                        Vans Authentic Canvas Trainers  allsole   vans
# 1                        Vans Authentic Canvas Trainers  allsole   vans
# 2                        Vans Authentic Canvas Trainers  allsole   vans
# 3                        Vans Authentic Canvas Trainers  allsole   vans
# 4                        Vans Authentic Canvas Trainers  allsole   vans
# ...                                                 ...      ...    ...
# 202555  Coach 1941 Black & Off-White Logo Slide Sandals   ssense  coach
# 202556  Coach 1941 Black & Off-White Logo Slide Sandals   ssense  coach
# 202557  Coach 1941 Black & Off-White Logo Slide Sandals   ssense  coach
# 202558  Coach 1941 Black & Off-White Logo Slide Sandals   ssense  coach
# 202559  Coach 1941 Black & Off-White Logo Slide Sandals   ssense  coach
#
#         gender        color   imid  \
# 0       unisex        Black  26789
# 1       unisex        Black  26790
# 2       unisex        Black  26791
# 3       unisex        Black  26792
# 4       unisex        Black  26793
# ...        ...          ...    ...
# 202555     men  Chalk black  95785
# 202556     men  Chalk black  95786
# 202557     men  Chalk black  95787
# 202558     men  Chalk black  95788
# 202559     men  Chalk black  95789
#
#                                                 image_url  \
# 0       https://aisle-3-image-final.s3.eu-west-2.amazo...
# 1       https://aisle-3-image-final.s3.eu-west-2.amazo...
# 2       https://aisle-3-image-final.s3.eu-west-2.amazo...
# 3       https://aisle-3-image-final.s3.eu-west-2.amazo...
# 4       https://aisle-3-image-final.s3.eu-west-2.amazo...
# ...                                                   ...
# 202555  https://aisle-3-image-final.s3.eu-west-2.amazo...
# 202556  https://aisle-3-image-final.s3.eu-west-2.amazo...
# 202557  https://aisle-3-image-final.s3.eu-west-2.amazo...
# 202558  https://aisle-3-image-final.s3.eu-west-2.amazo...
# 202559  https://aisle-3-image-final.s3.eu-west-2.amazo...
#
#                                                     image          pose
# 0       s3://aisle-3-image-final/images/original/allso...     side_shot
# 1       s3://aisle-3-image-final/images/original/allso...     side_shot
# 2       s3://aisle-3-image-final/images/original/allso...     side_shot
# 3       s3://aisle-3-image-final/images/original/allso...    upper_shot
# 4       s3://aisle-3-image-final/images/original/allso...  partial_shot
# ...                                                   ...           ...
# 202555  s3://aisle-3-image-final/images/original/ssens...  partial_shot
# 202556  s3://aisle-3-image-final/images/original/ssens...     pair_shot
# 202557  s3://aisle-3-image-final/images/original/ssens...     side_shot
# 202558  s3://aisle-3-image-final/images/original/ssens...     pair_shot
# 202559  s3://aisle-3-image-final/images/original/ssens...     pair_shot
#
# [202560 rows x 11 columns]

# %%
df.image = df.image.str.replace("s3://", "")
df.image
# Out:
# 0         aisle-3-image-final/images/original/allsole/al...
# 1         aisle-3-image-final/images/original/allsole/al...
# 2         aisle-3-image-final/images/original/allsole/al...
# 3         aisle-3-image-final/images/original/allsole/al...
# 4         aisle-3-image-final/images/original/allsole/al...
#                                 ...
# 202555    aisle-3-image-final/images/original/ssense/sse...
# 202556    aisle-3-image-final/images/original/ssense/sse...
# 202557    aisle-3-image-final/images/original/ssense/sse...
# 202558    aisle-3-image-final/images/original/ssense/sse...
# 202559    aisle-3-image-final/images/original/ssense/sse...
# Name: image, Length: 202560, dtype: object

# %%
(data_dir + df.image).apply(os.path.isfile).value_counts()
# Out:
# True    202560
# Name: image, dtype: int64

# %% [markdown]
# # Implementation
# From my experiments I found the following modifications to the plain **Phash** algorithm works well:
# - Increase the `hash-size` (size of the top left square of DCT frequencies taken for hash) to introduce a greater avalanche factor into the hashing function.
# - Repeate the calculation 3 times on the 3 color channels to extend Phash to be color sensitive.

# %%
import hashlib

import cv2
from PIL import Image
import numpy as np
import scipy.fftpack


def binary_to_hex(arr):
    bit_string = "".join(str(b) for b in 1 * arr.flatten())
    width = int(np.ceil(len(bit_string) / 4))
    return "{:0>{width}x}".format(int(bit_string, 2), width=width)


def phash_image(image, hash_size=10, highfreq_factor=6):
    img_size = hash_size * highfreq_factor
    # img = cv2.imread(image)
    img = Image.open(image).convert("RGB")
    # img = cv2.resize(img, (img_size, img_size), interpolation=cv2.INTER_AREA)
    img = img.resize((img_size, img_size), Image.ANTIALIAS)
    img = np.asarray(img)
    channel_hashes = list()
    channels = [img[:, :, i] for i in range(img.shape[2])]
    for channel in channels:
        dct = scipy.fftpack.dct(scipy.fftpack.dct(channel, axis=0), axis=1)
        dctlowfreq = dct[:hash_size, :hash_size]
        med = np.median(dctlowfreq)
        diff = dctlowfreq > med
        channel_hashes.append(binary_to_hex(diff))
    return "-".join(channel_hashes)


def md5_hash(file):
    hash_md5 = hashlib.md5()
    with open(file, "rb") as f:
        for chunk in iter(lambda: f.read(4096), b""):
            hash_md5.update(chunk)
    return hash_md5.hexdigest()

# %% [markdown]
# ### Perform hashing
# - phash image hash
# - md5 file hash

# %%
from tqdm.contrib.concurrent import process_map, thread_map

df["phash"] = pd.Series(
    process_map(
        phash_image,
        (data_dir + df.image).values,
        max_workers=20,
        chunksize=100,
    )
)

df["md5"] =  pd.Series(
    thread_map(
        md5_hash,
        (data_dir + df.image).values,
        max_workers=10,
        chunksize=100,
    )
)
# Out:
#   0%|          | 0/202560 [00:00<?, ?it/s]
# /home/sour4bh/.local/lib/python3.8/site-packages/PIL/Image.py:945: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /home/sour4bh/.local/lib/python3.8/site-packages/PIL/Image.py:945: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /home/sour4bh/.local/lib/python3.8/site-packages/PIL/Image.py:945: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /home/sour4bh/.local/lib/python3.8/site-packages/PIL/Image.py:945: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /home/sour4bh/.local/lib/python3.8/site-packages/PIL/Image.py:945: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
#   0%|          | 0/202560 [00:00<?, ?it/s]

# %% [markdown]
# # Duplicates

# %% [markdown]
# ### phash : How many duplicates are there?
# **distribution of image duplicates:**

# %%
df.phash.value_counts().value_counts().sort_index()
# Out:
# 1    198973
# 2      1737
# 3        27
# 4         8
# Name: phash, dtype: int64

# %% [markdown]
# ### md5 : How many duplicates are there?
# This shows that we have large part of the duplicates simply as actual image file duplicates. This is not to be understood as a very low recall of the Phashing function (technically we actually don't want recall).
# This is understandable given the main motive of this exercise -- removal of same merchant image duplicates.
#
# We will remove same md5 clusters later to isolate pHash clusters for an unbiased look.
#
# **distribution of file duplicates:**

# %%
df.md5.value_counts().value_counts().sort_index()
# Out:
# 1    200903
# 2       781
# 3        21
# 4         8
# Name: md5, dtype: int64

# %% [markdown]
# ## Let's visualize Image clusters with same pHashes

# %%
clusters = df.phash.value_counts().sort_values(ascending=False)
clusters
# Out:
# beb053e8e8c14fac10deda287-beb053e8e8c14fac10dbda287-beb053e8e8c14fac10dfda285    4
# afe35d015a911ca8f8c54e8d7-afe35d015a911ca8f8c54e8d7-afe35d017a911ca8f8c54e8d5    4
# e953996ac26953d96cc23133d-e9719968c26973d96cc23133d-e971d968c26973d96cc26131d    4
# b83e0dfb1f674dc18f006c0e3-b83e0dfb1f670dc18f026c0e3-b83e0dfb1f674dc18f006c0e3    4
# b913ec6cf193b1d2c64667231-f916fce4f093b8d0c64663239-f916dce4b893a8f0c74633239    4
#                                                                                 ..
# aba0143433c8c9faf4d5af0f4-aba014303bc8c9faf4b5af0f4-aba014303bc8c9faf4b5af0f4    1
# bfae48c702eb3c8c470be18da-bf2e48c703eb3c8c470be18da-bfae48c743eb388c470be18d8    1
# baef34825493a5c3e25d46f0c-facf34824493a5c3e2dd46f18-eecf3c824493a5c3ea9c46f18    1
# f671293b9819b191db84aef90-f671213f9019b191db84aef94-f6712137901bb191db843ef94    1
# bff84798078047685ce25bb2b-bff84798078447685ca25bb2b-bff84798078447685ca25bb2b    1
# Name: phash, Length: 200745, dtype: int64

# %% [markdown]
# ### Top 20 clusters by size:

# %%
phash_clusters = clusters.index.tolist()
for cluster in phash_clusters[:20]:
    iplt.plot_images(
        df[df.phash == cluster].image_url.values,
        show_url=False,
        img_width=150
    )
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-bw9kuDrTWPF9yrogEbpQUr {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-bw9kuDrTWPF9yrogEbpQUr {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-bw9kuDrTWPF9yrogEbpQUr {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-bw9kuDrTWPF9yrogEbpQUr:checked ~ #ipyplot-html-viewer-textarea-bw9kuDrTWPF9yrogEbpQUr {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-bw9kuDrTWPF9yrogEbpQUr:checked + #ipyplot-html-viewer-label-bw9kuDrTWPF9yrogEbpQUr:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-bw9kuDrTWPF9yrogEbpQUr">
#         <label id="ipyplot-html-viewer-label-bw9kuDrTWPF9yrogEbpQUr" for="ipyplot-html-viewer-toggle-bw9kuDrTWPF9yrogEbpQUr">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-bw9kuDrTWPF9yrogEbpQUr" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-dKM7PGCY2QtidwoxYhrB8f {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-dKM7PGCY2QtidwoxYhrB8f {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-dKM7PGCY2QtidwoxYhrB8f {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-dKM7PGCY2QtidwoxYhrB8f span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-dKM7PGCY2QtidwoxYhrB8f span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-dKM7PGCY2QtidwoxYhrB8f img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-dKM7PGCY2QtidwoxYhrB8f span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-dKM7PGCY2QtidwoxYhrB8f span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-dKM7PGCY2QtidwoxYhrB8f]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-dKM7PGCY2QtidwoxYhrB8f]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-dKM7PGCY2QtidwoxYhrB8f]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-dKM7PGCY2QtidwoxYhrB8f">
#     <div class="ipyplot-placeholder-div-dKM7PGCY2QtidwoxYhrB8f">
#         <div id="ipyplot-content-div-dKM7PGCY2QtidwoxYhrB8f-JSXDnKqdGwLD3pTfBoiD7M" class="ipyplot-content-div-dKM7PGCY2QtidwoxYhrB8f">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/asos/asos.1074065/ebcc17d8-668d-35be-90ec-ea8b9e244907"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-dKM7PGCY2QtidwoxYhrB8f-JSXDnKqdGwLD3pTfBoiD7M">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-dKM7PGCY2QtidwoxYhrB8f">
#         <div id="ipyplot-content-div-dKM7PGCY2QtidwoxYhrB8f-Fcy8348qBGWoKvvkmkY4vq" class="ipyplot-content-div-dKM7PGCY2QtidwoxYhrB8f">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/asos/asos.1376832/55ded56c-f96b-369a-acaf-7fc93a8231aa"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-dKM7PGCY2QtidwoxYhrB8f-Fcy8348qBGWoKvvkmkY4vq">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-dKM7PGCY2QtidwoxYhrB8f">
#         <div id="ipyplot-content-div-dKM7PGCY2QtidwoxYhrB8f-eHXehxkewZ5BYCbejdFMVn" class="ipyplot-content-div-dKM7PGCY2QtidwoxYhrB8f">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/asos/asos.1609456/8c57887a-3cd2-3a72-9f73-9304d9f45cfe"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-dKM7PGCY2QtidwoxYhrB8f-eHXehxkewZ5BYCbejdFMVn">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-dKM7PGCY2QtidwoxYhrB8f">
#         <div id="ipyplot-content-div-dKM7PGCY2QtidwoxYhrB8f-AnPihkRZSRXYyifa88m2Ld" class="ipyplot-content-div-dKM7PGCY2QtidwoxYhrB8f">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/asos/asos.1870356/71384ee7-013e-3e1d-a089-4d6925e114c3"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-dKM7PGCY2QtidwoxYhrB8f-AnPihkRZSRXYyifa88m2Ld">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-dKM7PGCY2QtidwoxYhrB8f {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-dKM7PGCY2QtidwoxYhrB8f {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-dKM7PGCY2QtidwoxYhrB8f {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-dKM7PGCY2QtidwoxYhrB8f span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-dKM7PGCY2QtidwoxYhrB8f span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-dKM7PGCY2QtidwoxYhrB8f img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-dKM7PGCY2QtidwoxYhrB8f span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-dKM7PGCY2QtidwoxYhrB8f span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-dKM7PGCY2QtidwoxYhrB8f]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-dKM7PGCY2QtidwoxYhrB8f]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-dKM7PGCY2QtidwoxYhrB8f]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-dKM7PGCY2QtidwoxYhrB8f">
#     <div class="ipyplot-placeholder-div-dKM7PGCY2QtidwoxYhrB8f">
#         <div id="ipyplot-content-div-dKM7PGCY2QtidwoxYhrB8f-JSXDnKqdGwLD3pTfBoiD7M" class="ipyplot-content-div-dKM7PGCY2QtidwoxYhrB8f">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/asos/asos.1074065/ebcc17d8-668d-35be-90ec-ea8b9e244907"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-dKM7PGCY2QtidwoxYhrB8f-JSXDnKqdGwLD3pTfBoiD7M">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-dKM7PGCY2QtidwoxYhrB8f">
#         <div id="ipyplot-content-div-dKM7PGCY2QtidwoxYhrB8f-Fcy8348qBGWoKvvkmkY4vq" class="ipyplot-content-div-dKM7PGCY2QtidwoxYhrB8f">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/asos/asos.1376832/55ded56c-f96b-369a-acaf-7fc93a8231aa"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-dKM7PGCY2QtidwoxYhrB8f-Fcy8348qBGWoKvvkmkY4vq">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-dKM7PGCY2QtidwoxYhrB8f">
#         <div id="ipyplot-content-div-dKM7PGCY2QtidwoxYhrB8f-eHXehxkewZ5BYCbejdFMVn" class="ipyplot-content-div-dKM7PGCY2QtidwoxYhrB8f">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/asos/asos.1609456/8c57887a-3cd2-3a72-9f73-9304d9f45cfe"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-dKM7PGCY2QtidwoxYhrB8f-eHXehxkewZ5BYCbejdFMVn">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-dKM7PGCY2QtidwoxYhrB8f">
#         <div id="ipyplot-content-div-dKM7PGCY2QtidwoxYhrB8f-AnPihkRZSRXYyifa88m2Ld" class="ipyplot-content-div-dKM7PGCY2QtidwoxYhrB8f">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/asos/asos.1870356/71384ee7-013e-3e1d-a089-4d6925e114c3"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-dKM7PGCY2QtidwoxYhrB8f-AnPihkRZSRXYyifa88m2Ld">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#     <style>
#         #ipyplot-html-viewer-toggle-ADAfgXjAXASiBpzSJawGoE {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-ADAfgXjAXASiBpzSJawGoE {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-ADAfgXjAXASiBpzSJawGoE {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-ADAfgXjAXASiBpzSJawGoE:checked ~ #ipyplot-html-viewer-textarea-ADAfgXjAXASiBpzSJawGoE {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-ADAfgXjAXASiBpzSJawGoE:checked + #ipyplot-html-viewer-label-ADAfgXjAXASiBpzSJawGoE:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-ADAfgXjAXASiBpzSJawGoE">
#         <label id="ipyplot-html-viewer-label-ADAfgXjAXASiBpzSJawGoE" for="ipyplot-html-viewer-toggle-ADAfgXjAXASiBpzSJawGoE">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-ADAfgXjAXASiBpzSJawGoE" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-WtdxozLDEMmvxxD9woMRYD {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-WtdxozLDEMmvxxD9woMRYD {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-WtdxozLDEMmvxxD9woMRYD {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-WtdxozLDEMmvxxD9woMRYD span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-WtdxozLDEMmvxxD9woMRYD span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-WtdxozLDEMmvxxD9woMRYD img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-WtdxozLDEMmvxxD9woMRYD span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-WtdxozLDEMmvxxD9woMRYD span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-WtdxozLDEMmvxxD9woMRYD]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-WtdxozLDEMmvxxD9woMRYD]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-WtdxozLDEMmvxxD9woMRYD]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-WtdxozLDEMmvxxD9woMRYD">
#     <div class="ipyplot-placeholder-div-WtdxozLDEMmvxxD9woMRYD">
#         <div id="ipyplot-content-div-WtdxozLDEMmvxxD9woMRYD-YSMAMQdvwFinhuHrL6XNuV" class="ipyplot-content-div-WtdxozLDEMmvxxD9woMRYD">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/eqvvs/eqvvs.6980139909315/b051f3f1-7722-3f10-a776-949ed5f7ceb9"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-WtdxozLDEMmvxxD9woMRYD-YSMAMQdvwFinhuHrL6XNuV">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-WtdxozLDEMmvxxD9woMRYD">
#         <div id="ipyplot-content-div-WtdxozLDEMmvxxD9woMRYD-crScm2e4srk9uZhv3sU9mx" class="ipyplot-content-div-WtdxozLDEMmvxxD9woMRYD">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/eqvvs/eqvvs.6980140859587/ff252204-df4f-35d3-91ff-df11554843bb"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-WtdxozLDEMmvxxD9woMRYD-crScm2e4srk9uZhv3sU9mx">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-WtdxozLDEMmvxxD9woMRYD">
#         <div id="ipyplot-content-div-WtdxozLDEMmvxxD9woMRYD-SS8RbcJigwo46pMGpRwPi7" class="ipyplot-content-div-WtdxozLDEMmvxxD9woMRYD">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/eqvvs/eqvvs.6980146069699/9719aa8f-6d34-319d-ac4c-a99505acf426"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-WtdxozLDEMmvxxD9woMRYD-SS8RbcJigwo46pMGpRwPi7">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-WtdxozLDEMmvxxD9woMRYD">
#         <div id="ipyplot-content-div-WtdxozLDEMmvxxD9woMRYD-fWguA5bGRBXZ7QrDH8uYtH" class="ipyplot-content-div-WtdxozLDEMmvxxD9woMRYD">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/eqvvs/eqvvs.6980147839171/2cd3bb1d-ad46-3fdb-977a-5ecd95253164"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-WtdxozLDEMmvxxD9woMRYD-fWguA5bGRBXZ7QrDH8uYtH">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-WtdxozLDEMmvxxD9woMRYD {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-WtdxozLDEMmvxxD9woMRYD {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-WtdxozLDEMmvxxD9woMRYD {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-WtdxozLDEMmvxxD9woMRYD span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-WtdxozLDEMmvxxD9woMRYD span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-WtdxozLDEMmvxxD9woMRYD img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-WtdxozLDEMmvxxD9woMRYD span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-WtdxozLDEMmvxxD9woMRYD span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-WtdxozLDEMmvxxD9woMRYD]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-WtdxozLDEMmvxxD9woMRYD]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-WtdxozLDEMmvxxD9woMRYD]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-WtdxozLDEMmvxxD9woMRYD">
#     <div class="ipyplot-placeholder-div-WtdxozLDEMmvxxD9woMRYD">
#         <div id="ipyplot-content-div-WtdxozLDEMmvxxD9woMRYD-YSMAMQdvwFinhuHrL6XNuV" class="ipyplot-content-div-WtdxozLDEMmvxxD9woMRYD">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/eqvvs/eqvvs.6980139909315/b051f3f1-7722-3f10-a776-949ed5f7ceb9"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-WtdxozLDEMmvxxD9woMRYD-YSMAMQdvwFinhuHrL6XNuV">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-WtdxozLDEMmvxxD9woMRYD">
#         <div id="ipyplot-content-div-WtdxozLDEMmvxxD9woMRYD-crScm2e4srk9uZhv3sU9mx" class="ipyplot-content-div-WtdxozLDEMmvxxD9woMRYD">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/eqvvs/eqvvs.6980140859587/ff252204-df4f-35d3-91ff-df11554843bb"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-WtdxozLDEMmvxxD9woMRYD-crScm2e4srk9uZhv3sU9mx">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-WtdxozLDEMmvxxD9woMRYD">
#         <div id="ipyplot-content-div-WtdxozLDEMmvxxD9woMRYD-SS8RbcJigwo46pMGpRwPi7" class="ipyplot-content-div-WtdxozLDEMmvxxD9woMRYD">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/eqvvs/eqvvs.6980146069699/9719aa8f-6d34-319d-ac4c-a99505acf426"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-WtdxozLDEMmvxxD9woMRYD-SS8RbcJigwo46pMGpRwPi7">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-WtdxozLDEMmvxxD9woMRYD">
#         <div id="ipyplot-content-div-WtdxozLDEMmvxxD9woMRYD-fWguA5bGRBXZ7QrDH8uYtH" class="ipyplot-content-div-WtdxozLDEMmvxxD9woMRYD">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/eqvvs/eqvvs.6980147839171/2cd3bb1d-ad46-3fdb-977a-5ecd95253164"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-WtdxozLDEMmvxxD9woMRYD-fWguA5bGRBXZ7QrDH8uYtH">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#     <style>
#         #ipyplot-html-viewer-toggle-4njom4RSyRECbCP7ds3wY4 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-4njom4RSyRECbCP7ds3wY4 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-4njom4RSyRECbCP7ds3wY4 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-4njom4RSyRECbCP7ds3wY4:checked ~ #ipyplot-html-viewer-textarea-4njom4RSyRECbCP7ds3wY4 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-4njom4RSyRECbCP7ds3wY4:checked + #ipyplot-html-viewer-label-4njom4RSyRECbCP7ds3wY4:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-4njom4RSyRECbCP7ds3wY4">
#         <label id="ipyplot-html-viewer-label-4njom4RSyRECbCP7ds3wY4" for="ipyplot-html-viewer-toggle-4njom4RSyRECbCP7ds3wY4">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-4njom4RSyRECbCP7ds3wY4" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-Ur5ZTYdVKZxtiv5dkGKs7q {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-Ur5ZTYdVKZxtiv5dkGKs7q {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-Ur5ZTYdVKZxtiv5dkGKs7q {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-Ur5ZTYdVKZxtiv5dkGKs7q span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-Ur5ZTYdVKZxtiv5dkGKs7q span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-Ur5ZTYdVKZxtiv5dkGKs7q img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-Ur5ZTYdVKZxtiv5dkGKs7q span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-Ur5ZTYdVKZxtiv5dkGKs7q span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-Ur5ZTYdVKZxtiv5dkGKs7q]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-Ur5ZTYdVKZxtiv5dkGKs7q]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-Ur5ZTYdVKZxtiv5dkGKs7q]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-Ur5ZTYdVKZxtiv5dkGKs7q">
#     <div class="ipyplot-placeholder-div-Ur5ZTYdVKZxtiv5dkGKs7q">
#         <div id="ipyplot-content-div-Ur5ZTYdVKZxtiv5dkGKs7q-ZBAMF4Xzgj3xXckK2udwtL" class="ipyplot-content-div-Ur5ZTYdVKZxtiv5dkGKs7q">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/spartoo/spartoo.17120396/e7705a71-9777-331a-805d-6af83eaa45ef"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Ur5ZTYdVKZxtiv5dkGKs7q-ZBAMF4Xzgj3xXckK2udwtL">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-Ur5ZTYdVKZxtiv5dkGKs7q">
#         <div id="ipyplot-content-div-Ur5ZTYdVKZxtiv5dkGKs7q-oCLGxE2pYdhyD5kNTLCPZf" class="ipyplot-content-div-Ur5ZTYdVKZxtiv5dkGKs7q">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/spartoo/spartoo.17120396/dde814c4-c938-3f5c-8b6f-d0a4765ed3a0"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Ur5ZTYdVKZxtiv5dkGKs7q-oCLGxE2pYdhyD5kNTLCPZf">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-Ur5ZTYdVKZxtiv5dkGKs7q">
#         <div id="ipyplot-content-div-Ur5ZTYdVKZxtiv5dkGKs7q-KFFt87VymPigXH5bNAxYKG" class="ipyplot-content-div-Ur5ZTYdVKZxtiv5dkGKs7q">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/spartoo/spartoo.17120396/22b9475d-0338-3d1f-be1b-b4ac0f6068b7"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Ur5ZTYdVKZxtiv5dkGKs7q-KFFt87VymPigXH5bNAxYKG">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-Ur5ZTYdVKZxtiv5dkGKs7q">
#         <div id="ipyplot-content-div-Ur5ZTYdVKZxtiv5dkGKs7q-Lv9XLpJwijWpSSQmV9fYq6" class="ipyplot-content-div-Ur5ZTYdVKZxtiv5dkGKs7q">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/spartoo/spartoo.17120396/232d23e6-fd96-3dce-b547-cf6507ca0f07"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Ur5ZTYdVKZxtiv5dkGKs7q-Lv9XLpJwijWpSSQmV9fYq6">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-Ur5ZTYdVKZxtiv5dkGKs7q {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-Ur5ZTYdVKZxtiv5dkGKs7q {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-Ur5ZTYdVKZxtiv5dkGKs7q {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-Ur5ZTYdVKZxtiv5dkGKs7q span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-Ur5ZTYdVKZxtiv5dkGKs7q span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-Ur5ZTYdVKZxtiv5dkGKs7q img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-Ur5ZTYdVKZxtiv5dkGKs7q span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-Ur5ZTYdVKZxtiv5dkGKs7q span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-Ur5ZTYdVKZxtiv5dkGKs7q]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-Ur5ZTYdVKZxtiv5dkGKs7q]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-Ur5ZTYdVKZxtiv5dkGKs7q]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-Ur5ZTYdVKZxtiv5dkGKs7q">
#     <div class="ipyplot-placeholder-div-Ur5ZTYdVKZxtiv5dkGKs7q">
#         <div id="ipyplot-content-div-Ur5ZTYdVKZxtiv5dkGKs7q-ZBAMF4Xzgj3xXckK2udwtL" class="ipyplot-content-div-Ur5ZTYdVKZxtiv5dkGKs7q">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/spartoo/spartoo.17120396/e7705a71-9777-331a-805d-6af83eaa45ef"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Ur5ZTYdVKZxtiv5dkGKs7q-ZBAMF4Xzgj3xXckK2udwtL">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-Ur5ZTYdVKZxtiv5dkGKs7q">
#         <div id="ipyplot-content-div-Ur5ZTYdVKZxtiv5dkGKs7q-oCLGxE2pYdhyD5kNTLCPZf" class="ipyplot-content-div-Ur5ZTYdVKZxtiv5dkGKs7q">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/spartoo/spartoo.17120396/dde814c4-c938-3f5c-8b6f-d0a4765ed3a0"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Ur5ZTYdVKZxtiv5dkGKs7q-oCLGxE2pYdhyD5kNTLCPZf">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-Ur5ZTYdVKZxtiv5dkGKs7q">
#         <div id="ipyplot-content-div-Ur5ZTYdVKZxtiv5dkGKs7q-KFFt87VymPigXH5bNAxYKG" class="ipyplot-content-div-Ur5ZTYdVKZxtiv5dkGKs7q">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/spartoo/spartoo.17120396/22b9475d-0338-3d1f-be1b-b4ac0f6068b7"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Ur5ZTYdVKZxtiv5dkGKs7q-KFFt87VymPigXH5bNAxYKG">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-Ur5ZTYdVKZxtiv5dkGKs7q">
#         <div id="ipyplot-content-div-Ur5ZTYdVKZxtiv5dkGKs7q-Lv9XLpJwijWpSSQmV9fYq6" class="ipyplot-content-div-Ur5ZTYdVKZxtiv5dkGKs7q">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/spartoo/spartoo.17120396/232d23e6-fd96-3dce-b547-cf6507ca0f07"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Ur5ZTYdVKZxtiv5dkGKs7q-Lv9XLpJwijWpSSQmV9fYq6">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#     <style>
#         #ipyplot-html-viewer-toggle-PyPNPZdksKDKvmp7MmFkqU {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-PyPNPZdksKDKvmp7MmFkqU {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-PyPNPZdksKDKvmp7MmFkqU {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-PyPNPZdksKDKvmp7MmFkqU:checked ~ #ipyplot-html-viewer-textarea-PyPNPZdksKDKvmp7MmFkqU {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-PyPNPZdksKDKvmp7MmFkqU:checked + #ipyplot-html-viewer-label-PyPNPZdksKDKvmp7MmFkqU:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-PyPNPZdksKDKvmp7MmFkqU">
#         <label id="ipyplot-html-viewer-label-PyPNPZdksKDKvmp7MmFkqU" for="ipyplot-html-viewer-toggle-PyPNPZdksKDKvmp7MmFkqU">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-PyPNPZdksKDKvmp7MmFkqU" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-WYwz5TvMFRAW7wAhzoBvfU {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-WYwz5TvMFRAW7wAhzoBvfU {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-WYwz5TvMFRAW7wAhzoBvfU {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-WYwz5TvMFRAW7wAhzoBvfU span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-WYwz5TvMFRAW7wAhzoBvfU span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-WYwz5TvMFRAW7wAhzoBvfU img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-WYwz5TvMFRAW7wAhzoBvfU span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-WYwz5TvMFRAW7wAhzoBvfU span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-WYwz5TvMFRAW7wAhzoBvfU]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-WYwz5TvMFRAW7wAhzoBvfU]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-WYwz5TvMFRAW7wAhzoBvfU]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-WYwz5TvMFRAW7wAhzoBvfU">
#     <div class="ipyplot-placeholder-div-WYwz5TvMFRAW7wAhzoBvfU">
#         <div id="ipyplot-content-div-WYwz5TvMFRAW7wAhzoBvfU-iQMf5Q8EzxGpqnR3UVMHfv" class="ipyplot-content-div-WYwz5TvMFRAW7wAhzoBvfU">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/asos/asos.110658479/57f05a7b-659f-34d6-8b46-e6bb9350d353"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-WYwz5TvMFRAW7wAhzoBvfU-iQMf5Q8EzxGpqnR3UVMHfv">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-WYwz5TvMFRAW7wAhzoBvfU">
#         <div id="ipyplot-content-div-WYwz5TvMFRAW7wAhzoBvfU-U7RdUFzGoBtaLw2q5wTjKS" class="ipyplot-content-div-WYwz5TvMFRAW7wAhzoBvfU">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/asos/asos.115184697/7d3a70b3-ed53-36d5-9bb8-e6ee9179f8ae"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-WYwz5TvMFRAW7wAhzoBvfU-U7RdUFzGoBtaLw2q5wTjKS">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-WYwz5TvMFRAW7wAhzoBvfU">
#         <div id="ipyplot-content-div-WYwz5TvMFRAW7wAhzoBvfU-4cF6HRknpBLhHxfnEnZrb9" class="ipyplot-content-div-WYwz5TvMFRAW7wAhzoBvfU">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/asos/asos.1480465/e0eeb75b-145d-3236-b269-d67c8910e852"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-WYwz5TvMFRAW7wAhzoBvfU-4cF6HRknpBLhHxfnEnZrb9">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-WYwz5TvMFRAW7wAhzoBvfU">
#         <div id="ipyplot-content-div-WYwz5TvMFRAW7wAhzoBvfU-gnXd22gSgWdgCfAcVTPNLc" class="ipyplot-content-div-WYwz5TvMFRAW7wAhzoBvfU">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/asos/asos.1480465/ef5d30df-1c3d-30db-ac6f-7ff66696f5af"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-WYwz5TvMFRAW7wAhzoBvfU-gnXd22gSgWdgCfAcVTPNLc">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-WYwz5TvMFRAW7wAhzoBvfU {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-WYwz5TvMFRAW7wAhzoBvfU {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-WYwz5TvMFRAW7wAhzoBvfU {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-WYwz5TvMFRAW7wAhzoBvfU span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-WYwz5TvMFRAW7wAhzoBvfU span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-WYwz5TvMFRAW7wAhzoBvfU img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-WYwz5TvMFRAW7wAhzoBvfU span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-WYwz5TvMFRAW7wAhzoBvfU span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-WYwz5TvMFRAW7wAhzoBvfU]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-WYwz5TvMFRAW7wAhzoBvfU]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-WYwz5TvMFRAW7wAhzoBvfU]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-WYwz5TvMFRAW7wAhzoBvfU">
#     <div class="ipyplot-placeholder-div-WYwz5TvMFRAW7wAhzoBvfU">
#         <div id="ipyplot-content-div-WYwz5TvMFRAW7wAhzoBvfU-iQMf5Q8EzxGpqnR3UVMHfv" class="ipyplot-content-div-WYwz5TvMFRAW7wAhzoBvfU">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/asos/asos.110658479/57f05a7b-659f-34d6-8b46-e6bb9350d353"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-WYwz5TvMFRAW7wAhzoBvfU-iQMf5Q8EzxGpqnR3UVMHfv">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-WYwz5TvMFRAW7wAhzoBvfU">
#         <div id="ipyplot-content-div-WYwz5TvMFRAW7wAhzoBvfU-U7RdUFzGoBtaLw2q5wTjKS" class="ipyplot-content-div-WYwz5TvMFRAW7wAhzoBvfU">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/asos/asos.115184697/7d3a70b3-ed53-36d5-9bb8-e6ee9179f8ae"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-WYwz5TvMFRAW7wAhzoBvfU-U7RdUFzGoBtaLw2q5wTjKS">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-WYwz5TvMFRAW7wAhzoBvfU">
#         <div id="ipyplot-content-div-WYwz5TvMFRAW7wAhzoBvfU-4cF6HRknpBLhHxfnEnZrb9" class="ipyplot-content-div-WYwz5TvMFRAW7wAhzoBvfU">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/asos/asos.1480465/e0eeb75b-145d-3236-b269-d67c8910e852"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-WYwz5TvMFRAW7wAhzoBvfU-4cF6HRknpBLhHxfnEnZrb9">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-WYwz5TvMFRAW7wAhzoBvfU">
#         <div id="ipyplot-content-div-WYwz5TvMFRAW7wAhzoBvfU-gnXd22gSgWdgCfAcVTPNLc" class="ipyplot-content-div-WYwz5TvMFRAW7wAhzoBvfU">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/asos/asos.1480465/ef5d30df-1c3d-30db-ac6f-7ff66696f5af"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-WYwz5TvMFRAW7wAhzoBvfU-gnXd22gSgWdgCfAcVTPNLc">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#     <style>
#         #ipyplot-html-viewer-toggle-MNzskLdfdMo3VrNteuKZVH {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-MNzskLdfdMo3VrNteuKZVH {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-MNzskLdfdMo3VrNteuKZVH {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-MNzskLdfdMo3VrNteuKZVH:checked ~ #ipyplot-html-viewer-textarea-MNzskLdfdMo3VrNteuKZVH {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-MNzskLdfdMo3VrNteuKZVH:checked + #ipyplot-html-viewer-label-MNzskLdfdMo3VrNteuKZVH:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-MNzskLdfdMo3VrNteuKZVH">
#         <label id="ipyplot-html-viewer-label-MNzskLdfdMo3VrNteuKZVH" for="ipyplot-html-viewer-toggle-MNzskLdfdMo3VrNteuKZVH">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-MNzskLdfdMo3VrNteuKZVH" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-bwFdirR5NckZeX7pagJxXa {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-bwFdirR5NckZeX7pagJxXa {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-bwFdirR5NckZeX7pagJxXa {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-bwFdirR5NckZeX7pagJxXa span.ipyplot-img-close {
#             display: none;
#         }
#
# ...
#             </a>
#             <a href="#ipyplot-content-div-hVS6jpseg5NJSH8mSwycPk-LxY7zgG5RQ6tKRCZzA7Vef">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-hVS6jpseg5NJSH8mSwycPk">
#         <div id="ipyplot-content-div-hVS6jpseg5NJSH8mSwycPk-PyJhxLaKh2rQCxLr9tiZDG" class="ipyplot-content-div-hVS6jpseg5NJSH8mSwycPk">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/sportsdirect/sportsdirect.06032490230/a233d868-b0b9-39e2-9be4-fefe50703867"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-hVS6jpseg5NJSH8mSwycPk-PyJhxLaKh2rQCxLr9tiZDG">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-hVS6jpseg5NJSH8mSwycPk">
#         <div id="ipyplot-content-div-hVS6jpseg5NJSH8mSwycPk-Le7KN4pyshf5zz63gKGjzf" class="ipyplot-content-div-hVS6jpseg5NJSH8mSwycPk">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/sportsdirect/sportsdirect.10088889235/c381c577-f7e7-328c-a309-483051f8af39"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-hVS6jpseg5NJSH8mSwycPk-Le7KN4pyshf5zz63gKGjzf">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-hVS6jpseg5NJSH8mSwycPk {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-hVS6jpseg5NJSH8mSwycPk {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-hVS6jpseg5NJSH8mSwycPk {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-hVS6jpseg5NJSH8mSwycPk span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-hVS6jpseg5NJSH8mSwycPk span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-hVS6jpseg5NJSH8mSwycPk img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-hVS6jpseg5NJSH8mSwycPk span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-hVS6jpseg5NJSH8mSwycPk span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-hVS6jpseg5NJSH8mSwycPk]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-hVS6jpseg5NJSH8mSwycPk]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-hVS6jpseg5NJSH8mSwycPk]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-hVS6jpseg5NJSH8mSwycPk">
#     <div class="ipyplot-placeholder-div-hVS6jpseg5NJSH8mSwycPk">
#         <div id="ipyplot-content-div-hVS6jpseg5NJSH8mSwycPk-LxY7zgG5RQ6tKRCZzA7Vef" class="ipyplot-content-div-hVS6jpseg5NJSH8mSwycPk">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/sportsdirect/sportsdirect.06032490230/5eb795ad-da4d-3556-812e-9dff0b76f267"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-hVS6jpseg5NJSH8mSwycPk-LxY7zgG5RQ6tKRCZzA7Vef">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-hVS6jpseg5NJSH8mSwycPk">
#         <div id="ipyplot-content-div-hVS6jpseg5NJSH8mSwycPk-PyJhxLaKh2rQCxLr9tiZDG" class="ipyplot-content-div-hVS6jpseg5NJSH8mSwycPk">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/sportsdirect/sportsdirect.06032490230/a233d868-b0b9-39e2-9be4-fefe50703867"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-hVS6jpseg5NJSH8mSwycPk-PyJhxLaKh2rQCxLr9tiZDG">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-hVS6jpseg5NJSH8mSwycPk">
#         <div id="ipyplot-content-div-hVS6jpseg5NJSH8mSwycPk-Le7KN4pyshf5zz63gKGjzf" class="ipyplot-content-div-hVS6jpseg5NJSH8mSwycPk">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/sportsdirect/sportsdirect.10088889235/c381c577-f7e7-328c-a309-483051f8af39"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-hVS6jpseg5NJSH8mSwycPk-Le7KN4pyshf5zz63gKGjzf">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#     <style>
#         #ipyplot-html-viewer-toggle-EAmDsKpHrUgUh6GSMwVBHn {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-EAmDsKpHrUgUh6GSMwVBHn {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-EAmDsKpHrUgUh6GSMwVBHn {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-EAmDsKpHrUgUh6GSMwVBHn:checked ~ #ipyplot-html-viewer-textarea-EAmDsKpHrUgUh6GSMwVBHn {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-EAmDsKpHrUgUh6GSMwVBHn:checked + #ipyplot-html-viewer-label-EAmDsKpHrUgUh6GSMwVBHn:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-EAmDsKpHrUgUh6GSMwVBHn">
#         <label id="ipyplot-html-viewer-label-EAmDsKpHrUgUh6GSMwVBHn" for="ipyplot-html-viewer-toggle-EAmDsKpHrUgUh6GSMwVBHn">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-EAmDsKpHrUgUh6GSMwVBHn" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-jCsYKkK63DYXwaN5d8AWkZ {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-jCsYKkK63DYXwaN5d8AWkZ {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-jCsYKkK63DYXwaN5d8AWkZ {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-jCsYKkK63DYXwaN5d8AWkZ span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-jCsYKkK63DYXwaN5d8AWkZ span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-jCsYKkK63DYXwaN5d8AWkZ img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-jCsYKkK63DYXwaN5d8AWkZ span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-jCsYKkK63DYXwaN5d8AWkZ span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-jCsYKkK63DYXwaN5d8AWkZ]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-jCsYKkK63DYXwaN5d8AWkZ]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-jCsYKkK63DYXwaN5d8AWkZ]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-jCsYKkK63DYXwaN5d8AWkZ">
#     <div class="ipyplot-placeholder-div-jCsYKkK63DYXwaN5d8AWkZ">
#         <div id="ipyplot-content-div-jCsYKkK63DYXwaN5d8AWkZ-boCnjvzibHq6w8aMPsLvg5" class="ipyplot-content-div-jCsYKkK63DYXwaN5d8AWkZ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/sportsdirect/sportsdirect.05028492260/248eb285-1383-34b7-92fe-736621d551b6"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-jCsYKkK63DYXwaN5d8AWkZ-boCnjvzibHq6w8aMPsLvg5">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-jCsYKkK63DYXwaN5d8AWkZ">
#         <div id="ipyplot-content-div-jCsYKkK63DYXwaN5d8AWkZ-B8SX9VEBbUTDgL3PvdsKwY" class="ipyplot-content-div-jCsYKkK63DYXwaN5d8AWkZ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/sportsdirect/sportsdirect.18229903270/8d99422b-45ff-3a78-8601-3fd4a2a56c3f"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-jCsYKkK63DYXwaN5d8AWkZ-B8SX9VEBbUTDgL3PvdsKwY">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-jCsYKkK63DYXwaN5d8AWkZ">
#         <div id="ipyplot-content-div-jCsYKkK63DYXwaN5d8AWkZ-FaE3ZQPVnncX999VysezNh" class="ipyplot-content-div-jCsYKkK63DYXwaN5d8AWkZ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/sportsdirect/sportsdirect.18229903270/88d54cbd-edf1-3244-9550-60d687b27450"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-jCsYKkK63DYXwaN5d8AWkZ-FaE3ZQPVnncX999VysezNh">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-jCsYKkK63DYXwaN5d8AWkZ {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-jCsYKkK63DYXwaN5d8AWkZ {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-jCsYKkK63DYXwaN5d8AWkZ {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-jCsYKkK63DYXwaN5d8AWkZ span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-jCsYKkK63DYXwaN5d8AWkZ span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-jCsYKkK63DYXwaN5d8AWkZ img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-jCsYKkK63DYXwaN5d8AWkZ span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-jCsYKkK63DYXwaN5d8AWkZ span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-jCsYKkK63DYXwaN5d8AWkZ]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-jCsYKkK63DYXwaN5d8AWkZ]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-jCsYKkK63DYXwaN5d8AWkZ]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-jCsYKkK63DYXwaN5d8AWkZ">
#     <div class="ipyplot-placeholder-div-jCsYKkK63DYXwaN5d8AWkZ">
#         <div id="ipyplot-content-div-jCsYKkK63DYXwaN5d8AWkZ-boCnjvzibHq6w8aMPsLvg5" class="ipyplot-content-div-jCsYKkK63DYXwaN5d8AWkZ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/sportsdirect/sportsdirect.05028492260/248eb285-1383-34b7-92fe-736621d551b6"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-jCsYKkK63DYXwaN5d8AWkZ-boCnjvzibHq6w8aMPsLvg5">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-jCsYKkK63DYXwaN5d8AWkZ">
#         <div id="ipyplot-content-div-jCsYKkK63DYXwaN5d8AWkZ-B8SX9VEBbUTDgL3PvdsKwY" class="ipyplot-content-div-jCsYKkK63DYXwaN5d8AWkZ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/sportsdirect/sportsdirect.18229903270/8d99422b-45ff-3a78-8601-3fd4a2a56c3f"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-jCsYKkK63DYXwaN5d8AWkZ-B8SX9VEBbUTDgL3PvdsKwY">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-jCsYKkK63DYXwaN5d8AWkZ">
#         <div id="ipyplot-content-div-jCsYKkK63DYXwaN5d8AWkZ-FaE3ZQPVnncX999VysezNh" class="ipyplot-content-div-jCsYKkK63DYXwaN5d8AWkZ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/sportsdirect/sportsdirect.18229903270/88d54cbd-edf1-3244-9550-60d687b27450"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-jCsYKkK63DYXwaN5d8AWkZ-FaE3ZQPVnncX999VysezNh">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>

# %% [markdown]
# ## Do some in-notebook annotation:
# We can see that some of these clusters are due to dirty non-product images so that the pose estimation missed out on, so let's annotate them out for now!

# %%
from pigeon import annotate
from IPython.display import display, Image

df.set_index("phash", drop=False, inplace=True)


def display_fn(phash):
    frame = df[df.phash == phash]
    iplt.plot_images(
        frame.image_url.values,
        labels=frame.id.values,
        custom_texts=(
            "<HR>"
            + frame[
                [
                    "pose",
                    "title",
                ]
            ].apply("<HR>".join, axis=1)
            + "<HR>"
            + frame[["brand", "merchant", "color"]].apply(" - ".join, axis=1)
        ).values,
        show_url=False,
        img_width=150,
    )


annotations = annotate(
    phash_clusters, options=["Bad Image"], include_skip=True, display_fn=display_fn
)
# Out:
# HTML(value='0 examples annotated, 200746 examples left')
# HBox(children=(Button(description='Bad Image', style=ButtonStyle()), Button(description='skip', style=ButtonSt…
# Output()

# %% [markdown]
# ### Dirty / non-descriptive images:
# I collected the following bad images by trimming the big clusters from the top, after a point these kind of images were hard to come by. We don't really have a lot of bad images (just a lot of duplicates of a few bad ones).
# **Pose estimation** can help here so that we don't use broken images, box shots, sole angles, charts/guides/anything that doesn't show the product -- as these images could be common to multiple non-identical offers.

# %%
bad_images = [x[0] for x in annotations]
iplt.plot_images(
    df[df.phash.isin(bad_images)].drop_duplicates("phash").image_url,
    show_url=False,
)
df = df.loc[~df.phash.isin(bad_images)].reset_index(drop=True)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-b46XC94KJzBgJBYgDN7K5b {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-b46XC94KJzBgJBYgDN7K5b {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-b46XC94KJzBgJBYgDN7K5b {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-b46XC94KJzBgJBYgDN7K5b:checked ~ #ipyplot-html-viewer-textarea-b46XC94KJzBgJBYgDN7K5b {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-b46XC94KJzBgJBYgDN7K5b:checked + #ipyplot-html-viewer-label-b46XC94KJzBgJBYgDN7K5b:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-b46XC94KJzBgJBYgDN7K5b">
#         <label id="ipyplot-html-viewer-label-b46XC94KJzBgJBYgDN7K5b" for="ipyplot-html-viewer-toggle-b46XC94KJzBgJBYgDN7K5b">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-b46XC94KJzBgJBYgDN7K5b" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-7SJyTuQ57nPLAbj3WY5MuR {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-7SJyTuQ57nPLAbj3WY5MuR {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-7SJyTuQ57nPLAbj3WY5MuR {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-7SJyTuQ57nPLAbj3WY5MuR span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-7SJyTuQ57nPLAbj3WY5MuR span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-7SJyTuQ57nPLAbj3WY5MuR img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-7SJyTuQ57nPLAbj3WY5MuR span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-7SJyTuQ57nPLAbj3WY5MuR span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-7SJyTuQ57nPLAbj3WY5MuR]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-7SJyTuQ57nPLAbj3WY5MuR]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-7SJyTuQ57nPLAbj3WY5MuR]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-7SJyTuQ57nPLAbj3WY5MuR">
#     <div class="ipyplot-placeholder-div-7SJyTuQ57nPLAbj3WY5MuR">
#         <div id="ipyplot-content-div-7SJyTuQ57nPLAbj3WY5MuR-cmQ8f8MLPVJJQt3aUwRYqK" class="ipyplot-content-div-7SJyTuQ57nPLAbj3WY5MuR">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/eqvvs/eqvvs.6980139909315/b051f3f1-7722-3f10-a776-949ed5f7ceb9"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-7SJyTuQ57nPLAbj3WY5MuR-cmQ8f8MLPVJJQt3aUwRYqK">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-7SJyTuQ57nPLAbj3WY5MuR">
#         <div id="ipyplot-content-div-7SJyTuQ57nPLAbj3WY5MuR-dSP2kFvksrBbtBw2oEzD24" class="ipyplot-content-div-7SJyTuQ57nPLAbj3WY5MuR">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/sportsdirect/sportsdirect.18108303270/644ee25b-f51a-3ab9-89c5-ef5396698c16"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-7SJyTuQ57nPLAbj3WY5MuR-dSP2kFvksrBbtBw2oEzD24">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-7SJyTuQ57nPLAbj3WY5MuR {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-7SJyTuQ57nPLAbj3WY5MuR {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-7SJyTuQ57nPLAbj3WY5MuR {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-7SJyTuQ57nPLAbj3WY5MuR span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-7SJyTuQ57nPLAbj3WY5MuR span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-7SJyTuQ57nPLAbj3WY5MuR img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-7SJyTuQ57nPLAbj3WY5MuR span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-7SJyTuQ57nPLAbj3WY5MuR span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-7SJyTuQ57nPLAbj3WY5MuR]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-7SJyTuQ57nPLAbj3WY5MuR]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-7SJyTuQ57nPLAbj3WY5MuR]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-7SJyTuQ57nPLAbj3WY5MuR">
#     <div class="ipyplot-placeholder-div-7SJyTuQ57nPLAbj3WY5MuR">
#         <div id="ipyplot-content-div-7SJyTuQ57nPLAbj3WY5MuR-cmQ8f8MLPVJJQt3aUwRYqK" class="ipyplot-content-div-7SJyTuQ57nPLAbj3WY5MuR">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/eqvvs/eqvvs.6980139909315/b051f3f1-7722-3f10-a776-949ed5f7ceb9"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-7SJyTuQ57nPLAbj3WY5MuR-cmQ8f8MLPVJJQt3aUwRYqK">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-7SJyTuQ57nPLAbj3WY5MuR">
#         <div id="ipyplot-content-div-7SJyTuQ57nPLAbj3WY5MuR-dSP2kFvksrBbtBw2oEzD24" class="ipyplot-content-div-7SJyTuQ57nPLAbj3WY5MuR">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="https://aisle-3-image-final.s3.eu-west-2.amazonaws.com/images/original/sportsdirect/sportsdirect.18108303270/644ee25b-f51a-3ab9-89c5-ef5396698c16"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-7SJyTuQ57nPLAbj3WY5MuR-dSP2kFvksrBbtBw2oEzD24">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>

# %% [markdown]
# ## Graph connected components
#
# If two offers **(either from the same merchant or from different merchants)** have any image which is duplicated in both these offers, then that counts as an "edge" connecting said two offers.
# Once the Graph is built we look at the connected components to find product clusters of offers.

# %%
import networkx as nx

G = nx.Graph()
for phash, phash_group in df.groupby("phash"):
    nodes = phash_group.id.unique()
    if len(nodes) > 1:
        for i in range(len(nodes) - 1):
            G.add_edge(nodes[i], nodes[i + 1])
print(
    f"Number of nodes : {G.number_of_nodes()}; Number of edges : {G.number_of_edges()}"
)
clusters = sorted(list(nx.connected_components(G)), key=len, reverse=True)
print(f"Number of clusters : {len(clusters)}")
# Out:
# Number of nodes : 1091; Number of edges : 550
# Number of clusters : 541

# %% [markdown]
# ### Cluster size distribution

# %%
pd.Series(clusters).apply(len).value_counts()
# Out:
# 2    533
# 3      7
# 4      1
# dtype: int64

# %% [markdown]
# ## Visualize product clusters

# %%
df.set_index("id", drop=False, inplace=True)

def visualize_cluster(df):
    df = df.copy().reset_index(drop=True)
    iplt.plot_images(
            df.image_url,
            labels=df.id,
            custom_texts="<HR>"
            + "<b>"
            + df["title"]
            + "</b>"
            + "<HR>"
            + df[["merchant", "brand", "gender", "color"]].apply(" - ".join, axis=1)
            + "<HR>"
            + df.pose,
            img_width=200,
            show_url=False,
            max_images=len(df),
        )

for cluster in clusters[:100]:
    visualize_cluster(df.loc[cluster])

# %% [markdown]
# # Randomly sample 100 more clusters

# %%
for cluster in random.choices(clusters, k=50):
    visualize_cluster(df.loc[cluster])

# %% [markdown]
# ## What merchants are matched by phashing?

# %%
cluster_merchants = list()
for cluster in clusters:
    merchants = df.loc[cluster].merchant.unique()
    if len(merchants) > 1:
        cluster_merchants.append([m.upper() for m in merchants])
    else:
        cluster_merchants.append(merchants.tolist() * 2)

pd.Series(list(map(" <-> ".join, np.sort(cluster_merchants, axis=1)))).value_counts()
# Out:
# ALLSOLE <-> COGGLES                246
# asos <-> asos                       97
# sportsdirect <-> sportsdirect       58
# schuh <-> schuh                     49
# NIKE <-> SPORTSDIRECT               39
# end clothing <-> end clothing       12
# ssense <-> ssense                   11
# spartoo.co.uk <-> spartoo.co.uk      7
# new balance <-> new balance          7
# FOOT LOCKER <-> NEW BALANCE          3
# camper <-> camper                    3
# clarks <-> clarks                    3
# coggles <-> coggles                  2
# nike <-> nike                        2
# jd sports <-> jd sports              1
# footasylum <-> footasylum            1
# dtype: int64

# %% [markdown]
# # Conclusion
# - For this technique to be used to get free product-matching matches we need to first pass these images through an outlier check and also discard singals from non-descriptive images since they are prone to give False Positives.
#
# - Finding connected components retaining only the stronger connections does avert the absence of a pose estimation pass, and this can easily be used as "free" ground-truth product-matching.
#
# - For the purpose of image data cleaning / processing we can easily implement this technique.
#
# - This technique also bootstraps some text product-matching data as we collect matching product titles by matching solely using images.

# %%
pd.Series(clusters).to_json("s3://aisle3-ml-datasets/phash_clusters.json", orient="records", indent=1)

# %%
df["label"] = df.id.astype("category").cat.codes
for cluster in clusters:
    df.loc[cluster, "label"] = uuid.uuid4()

# %%
df = df.drop_duplicates("phash", keep="first").reset_index(drop=True)
df.label = df.label.astype("category").cat.codes
df
# Out:
#                           id            variant_id  \
# 0           allsole.10491511      allsole.10491633
# 1           allsole.10491511      allsole.10491633
# 2           allsole.10491511      allsole.10491633
# 3           allsole.10491511      allsole.10491633
# 4           allsole.10491511      allsole.10491633
# ...                      ...                   ...
# 200738  ssense.221903M237021  ssense.221903M237021
# 200739  ssense.221903M237021  ssense.221903M237021
# 200740  ssense.221903M237021  ssense.221903M237021
# 200741  ssense.221903M237021  ssense.221903M237021
# 200742  ssense.221903M237021  ssense.221903M237021
#
#                                                   title merchant  brand  \
# 0                        Vans Authentic Canvas Trainers  allsole   vans
# 1                        Vans Authentic Canvas Trainers  allsole   vans
# 2                        Vans Authentic Canvas Trainers  allsole   vans
# 3                        Vans Authentic Canvas Trainers  allsole   vans
# 4                        Vans Authentic Canvas Trainers  allsole   vans
# ...                                                 ...      ...    ...
# 200738  Coach 1941 Black & Off-White Logo Slide Sandals   ssense  coach
# 200739  Coach 1941 Black & Off-White Logo Slide Sandals   ssense  coach
# 200740  Coach 1941 Black & Off-White Logo Slide Sandals   ssense  coach
# 200741  Coach 1941 Black & Off-White Logo Slide Sandals   ssense  coach
# 200742  Coach 1941 Black & Off-White Logo Slide Sandals   ssense  coach
#
#         gender        color   imid  \
# 0       unisex        Black  26789
# 1       unisex        Black  26790
# 2       unisex        Black  26791
# 3       unisex        Black  26792
# 4       unisex        Black  26793
# ...        ...          ...    ...
# 200738     men  Chalk black  95785
# 200739     men  Chalk black  95786
# 200740     men  Chalk black  95787
# 200741     men  Chalk black  95788
# 200742     men  Chalk black  95789
#
#                                                 image_url  \
# 0       https://aisle-3-image-final.s3.eu-west-2.amazo...
# 1       https://aisle-3-image-final.s3.eu-west-2.amazo...
# 2       https://aisle-3-image-final.s3.eu-west-2.amazo...
# 3       https://aisle-3-image-final.s3.eu-west-2.amazo...
# 4       https://aisle-3-image-final.s3.eu-west-2.amazo...
# ...                                                   ...
# 200738  https://aisle-3-image-final.s3.eu-west-2.amazo...
# 200739  https://aisle-3-image-final.s3.eu-west-2.amazo...
# 200740  https://aisle-3-image-final.s3.eu-west-2.amazo...
# 200741  https://aisle-3-image-final.s3.eu-west-2.amazo...
# 200742  https://aisle-3-image-final.s3.eu-west-2.amazo...
#
#                                                     image          pose  \
# 0       aisle-3-image-final/images/original/allsole/al...     side_shot
# 1       aisle-3-image-final/images/original/allsole/al...     side_shot
# 2       aisle-3-image-final/images/original/allsole/al...     side_shot
# 3       aisle-3-image-final/images/original/allsole/al...    upper_shot
# 4       aisle-3-image-final/images/original/allsole/al...  partial_shot
# ...                                                   ...           ...
# 200738  aisle-3-image-final/images/original/ssense/sse...  partial_shot
# 200739  aisle-3-image-final/images/original/ssense/sse...     pair_shot
# 200740  aisle-3-image-final/images/original/ssense/sse...     side_shot
# 200741  aisle-3-image-final/images/original/ssense/sse...     pair_shot
# 200742  aisle-3-image-final/images/original/ssense/sse...     pair_shot
#
#                                                     phash  \
# 0       aff00c80ffd01b337b006ccde-aff40c80ffd01a337b00...
# 1       fea15c98da845223fb91e446e-f6a15c98fa845223fb99...
# 2       aba51ec0e7931a89d54a6fa15-aba51ec0e7931a89d54a...
# 3       e7a66ce0e29c599987399a499-e7a66c60e69c59998739...
# 4       bc8d2d0f0f4b73c9d128d24e5-bc8d0c0f2f4b71c9d1a8...
# ...                                                   ...
# 200738  baf905ac67e514ba9542c00ff-baf905ac67e514ba9542...
# 200739  ffe007805ec5ca7b805ec45e6-ffe007805ec5ca7b805e...
# 200740  eeac14fb32b053ef8217d21a2-eeac54fb32b053ef8017...
# 200741  ffaa46cb15804f2ccb1dc20de-ffaa46ca15804f2ccb1d...
# 200742  bff84798078047685ce25bb2b-bff84798078447685ca2...
#
#                                      md5  label
# 0       22e646989821796152307bef73fbc568      0
# 1       2875924f6d79dd99bc669cdbe84d82c7      0
# 2       5da5243580c580f0cce4bfd54f6dd35a      0
# 3       f28aae91e89aa1de723d993580253b61      0
# 4       393a50c1c362a7189130a944ee897f73      0
# ...                                  ...    ...
# 200738  fd39a5006695521400f9849a3aeb67de  45263
# 200739  7cf2113b8e0c1710499bddd7df584fe3  45263
# 200740  f8553fbe9f45b50038b60cd6583af1a3  45263
# 200741  7ad47c5d9bacfa208d68545964717006  45263
# 200742  dd8c5fbf5c05f18086ae1841e2589475  45263
#
# [200743 rows x 14 columns]

# %%
df.image = "s3://" + df.image
# df.drop(columns=["phash", "md5"], inplace=True)
df.to_parquet("s3://aisle3-ml-datasets/product-matching/aisle3/deduped.parquet")
